# %%
# import calamancy for dependency parsing
import calamancy
import tl_calamancy_trf
print(calamancy.models())

nlp = tl_calamancy_trf.load()

#doc = nlp("Kumain is Juan sa Rizal kanina.")
#calamancy_model_trf = calamancy.load("tl_calamancy_trf-0.2.0", "tl-calamancy-trf" = 0.2 )
# Out:
# ['tl_calamancy_md-0.2.0', 'tl_calamancy_lg-0.2.0', 'tl_calamancy_trf-0.2.0', 'tl_calamancy_md-0.1.0', 'tl_calamancy_lg-0.1.0', 'tl_calamancy_trf-0.1.0']
# c:\Users\Neptune\Documents\GitHub\Thesis Heavy Duty\lib\site-packages\spacy\util.py:918: UserWarning: [W094] Model 'tl_calamancy_trf' (0.2.0) specifies an under-constrained spaCy version requirement: >=3.8.3. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.8.3,<3.9.0
#   warnings.warn(warn_msg)
# c:\Users\Neptune\Documents\GitHub\Thesis Heavy Duty\lib\site-packages\spacy_transformers\layers\hf_shim.py:137: UserWarning: Error loading saved torch state_dict with strict=True, likely due to differences between 'transformers' versions. Attempting to load with strict=False as a fallback...
#
# If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current 'transformers' and 'spacy-transformers' versions. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
tl_inp_list = ['Nabali ang bintana dahil sa larangan ng minahan.',
 'Ang bukid ng minahan ay nasa mesa.',
 'Matatag ang minahan.',
 'Sumabog ang larangan ng minahan.',
 'Ang larangan ng minahan ay yari sa metal.',
 'Ibinigay sa akin ng may - ari ang minahan.']

# %%
tl_docs = nlp_calamancy.pipe(tl_inp_list)

for doc in tl_docs:
    print(doc)
    for t in doc:
        print(t,t.dep_)
# Out:
# Nabali ang bintana dahil sa larangan ng minahan.
# Nabali ROOT
# ang det
# bintana nsubj
# dahil case
# sa fixed
# larangan advcl
# ng case
# minahan nmod
# . punct
# Ang bukid ng minahan ay nasa mesa.
# Ang det
# bukid nsubj
# ng case
# minahan nmod
# ay discourse
# nasa case
# mesa ROOT
# . punct
# Matatag ang minahan.
# Matatag ROOT
# ang det
# minahan nsubj
# . punct
# Sumabog ang larangan ng minahan.
# Sumabog ROOT
# ang det
# larangan nsubj
# ng case
# minahan nmod:poss
# . punct
# Ang larangan ng minahan ay yari sa metal.
# Ang det
# larangan nsubj
# ng case
# minahan nmod:poss
# ay discourse
# yari ROOT
# sa case
# metal nmod
# . punct
# Ibinigay sa akin ng may - ari ang minahan.
# Ibinigay ROOT
# sa case
# akin obl
# ng case
# may compound
# - punct
# ari obj:agent
# ang det
# minahan nsubj
# . punct

# %%
from spacy import displacy

vocab_dict_tl = {}

for t in tl_inp_list:
    doc = nlp(t)
    for token in doc:
        print(token, token.dep_)
        if token.dep_ == "nsubj":
            if str(token) not in vocab_dict_tl.keys():
                vocab_dict_tl[str(token)] = 1
            else: 
                vocab_dict_tl[str(token)] += 1
    displacy.render(doc, style='dep',jupyter=True)
    print("==================")

vocab_dict_tl

# %%
# import spacytrf for dependency parsing in english
import spacy

nlp_spacy = spacy.load('en_core_web_trf')

# %%
en_inp_list = ['The delinquent eats pizza.',
 'The delinquent is in the store.',
 'The delinquent is happy.',
 'The delinquent is running.',
 'The delinquent was invited to the party.',
 'I was given a gift from the delinquent.']

# %%
vocab_dict_en = {}

for t in en_inp_list:
    doc = nlp_spacy(t)
    for token in doc:
        print(token, token.dep_)
        if token.dep_ == "nsubj":
            if str(token) not in vocab_dict_en.keys():
                vocab_dict_en[str(token)] = 1
            else: 
                vocab_dict_en[str(token)] += 1
    print("==================")

vocab_dict_en

# %% [markdown]
# # Actual implementation

# %%
# imports
# import calamancy for dependency parsing
# import spacytrf for dependency parsing in english

import spacy
import calamancy
import tl_calamancy_trf

nlp_calamancy = tl_calamancy_trf.load()
nlp_spacy = spacy.load('en_core_web_trf')

# config
print(nlp_calamancy.pipe_names)
nlp_calamancy.disable_pipe('ner')
print(nlp_calamancy.pipe_names)
print(nlp_spacy.pipe_names)
nlp_spacy.disable_pipes(['attribute_ruler', 'lemmatizer', 'ner'])
print(nlp_spacy.pipe_names)
# Out:
# c:\Users\Neptune\Documents\GitHub\Thesis Heavy Duty\lib\site-packages\spacy\util.py:918: UserWarning: [W094] Model 'tl_calamancy_trf' (0.2.0) specifies an under-constrained spaCy version requirement: >=3.8.3. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.8.3,<3.9.0
#   warnings.warn(warn_msg)
# c:\Users\Neptune\Documents\GitHub\Thesis Heavy Duty\lib\site-packages\spacy_transformers\layers\hf_shim.py:137: UserWarning: Error loading saved torch state_dict with strict=True, likely due to differences between 'transformers' versions. Attempting to load with strict=False as a fallback...
#
# If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current 'transformers' and 'spacy-transformers' versions. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ['transformer', 'trainable_lemmatizer', 'tagger', 'morphologizer', 'parser', 'ner']
# ['transformer', 'trainable_lemmatizer', 'tagger', 'morphologizer', 'parser']
# ['transformer', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# ['transformer', 'tagger', 'parser']

# %%
# for ETA
from datetime import timedelta,datetime

def calamancy_dp(sentence_list, batch_size=64): # processes the text in batches then returns a list of calamancy docs
    doc_list_master = [] # batching is needed for checkpoints
    eta_rolling_average = [timedelta(0),timedelta(0),timedelta(0),timedelta(0),timedelta(0)]
    batch_index=0
    
    # splits the list into batches
    batched_sentences = [sentence_list[i:i + batch_size] for i in range(0, len(sentence_list), batch_size)]
    batched_sentences_len = len(batched_sentences)

    try:
        for sentence_list_batch in batched_sentences: # get the list of doc
            if batch_index % 2 == 0: # check eta every couple of batches
                start_time = datetime.now()
                doc_list_small = nlp_calamancy.pipe(sentence_list_batch)
                doc_list_master += doc_list_small
                end_time = datetime.now()
                batch_index += 1

                # measure ETA
                time_elapsed = ((end_time - start_time) * (batched_sentences_len - batch_index))
                eta_rolling_average.pop(0)
                eta_rolling_average.append(time_elapsed)
                eta = (sum(eta_rolling_average, timedelta(0))/5)
                print(f"calamancy dependecy parsing - parsed: {batch_index*batch_size} ETA: {eta}")
            else:
                doc_list_small = nlp_calamancy.pipe(sentence_list_batch)
                doc_list_master += doc_list_small
                batch_index += 1
        return doc_list_master

    except Exception as e: #if interrupted unexpectedly, save progress
        print(e)
        print("calamancy was unexpectedly stopped. Here's the progress.")
        a = {"batch_index" : batch_index, "master_list" : doc_list_master}
        print(a)
        return a

#def spacy_dp(sentence_list, batch_size=64): # processes the text in batches then returns a list of spacy docs
#    doc_list_master = [] # batching is needed for checkpoints
#    eta_rolling_average = [0,0,0,0,0]
#    batch_index=0
#    
#    # splits the list into batches
#    batched_sentences = [sentence_list[i:i + batch_size] for i in range(0, len(sentence_list), batch_size)]
#    batched_sentences_len = len(batched_sentences)
#
#    try:
#        for sentence_list_batch in batched_sentences: # get the list of doc
#            if batch_index % 2 == 0: # check eta every couple of batches
#                start_time = datetime.now()
#                doc_list_small = nlp_spacy.pipe(sentence_list_batch)
#                doc_list_master += doc_list_small
#                end_time = datetime.now()
#                batch_index += 1
#
#                # measure ETA
#                time_elapsed = ((end_time - start_time) * (batched_sentences_len - batch_index))
#                eta_rolling_average.pop(0)
#                eta_rolling_average.append(time_elapsed)
#                eta = (sum(eta_rolling_average)/5)
#                print(f"spacy dependecy parsing - parsed: {batch_index*batch_size} ETA: {eta}")
#            else:
#                doc_list_small = nlp_calamancy.pipe(sentence_list_batch)
#                doc_list_master += doc_list_small
#                batch_index += 1
#
#    except Exception as e: #if interrupted unexpectedly, save progress
#        print(e)
#        print("calamancy was unexpectedly stopped. Here's the progress.")
#        a = {"batch_index" : batch_index, "master_list" : doc_list_master}
#        print(a)
#        return a
#

# %%
def docList_to_nsubjList(doc_list): # returns a dictionary list of the tallies of the words that got counted as the nsubj
    outputList = []
    for doc in doc_list:
        output_mini = []
        for token in doc:
            if token.dep_ == 'nsubj':
                output_mini.append(token)
        outputList.append(output_mini)
    return outputList

# %%
import pandas as pd
# small scale test just to get and idea for an ETA

test_df = pd.read_csv("translated_helsinki.csv")['translated_en_helsinki'].sample(1000)
test_inp = test_df.tolist()

qq = calamancy_dp(test_inp)
print(qq)
ww = docList_to_nsubjList(qq)
ww
# Out:
# calamancy dependecy parsing - parsed: 64 ETA: 0:00:04.630245
# calamancy dependecy parsing - parsed: 192 ETA: 0:00:09.141180
# calamancy dependecy parsing - parsed: 320 ETA: 0:00:12.588644
# calamancy dependecy parsing - parsed: 448 ETA: 0:00:15.158014
# calamancy dependecy parsing - parsed: 576 ETA: 0:00:17.248032
# calamancy dependecy parsing - parsed: 704 ETA: 0:00:13.992982
# calamancy dependecy parsing - parsed: 832 ETA: 0:00:10.262690
# calamancy dependecy parsing - parsed: 960 ETA: 0:00:07.109845
# [Nabali ng tagasunod ng kampo ang bintana., Ang may - ari ay nagbigay sa paniking kumakain ng karne ng ilang pagkain., Ang gal ay inanyayahan sa partido., Ang pangkat ay nagbigay ng gantimpala sa pagtitiwarik., Nabali ang bintana dahil sa heteroploid., Ang resort ay yari sa metal., Ang pagsubok sa screen ay nangyari., Naganap ang pagmomodelo., Nabali ng dar al-islam ang bintana., Ang kapatid na kaluluwa ay inanyayahan sa partido., Kinain ng powderer ang pizza., Sumabog ang bangin., Dinadalaw ng mga tao ang magnetikong meridyano., Naglunsad ang picket ng isang bagong produkto., Ang hayop sa kabundukan ay mapaglaro., Ang bard ay kumain ng pizza., Ang dalawang wika ay tumatakbo., Ang takip ng katawan ay matibay., Ang attendant ay inanyayahan sa partido., Maligaya ang obserhista., Nabali ang bintana dahil sa patag., Ang pizza ay kinain ng trumpetero., Sumabog ang bodega ng bagyo., Ang lumaon ay inanyayahan sa patimpalak., Ibinigay sa akin ng may - ari ang defender., Ang knell ay matagumpay., Ang pandinig ay matagumpay., Ang mga prayleng austin ay itinatag noong 1990., Maligaya ang gladiator., Ang mainit na upuan ay nangyari., Ang pintor ng eksena ay inanyayahan sa partido., Sumabog ang alperes., Ibinigay sa akin ng may - ari ang ugat na mandrake., Nasa mesa ang masonerya ng mga cyclopean., Ang baseboard ay yari sa metal., Ang mga magbubukid ay tumatakbo., Ang larangan ng karangalan ay umuunlad., Ang pagsasanib ay sa Sabado., Kinain ng part-owner ang pizza., Ang demagoguery ay matagumpay., Ibinigay sa akin ng may - ari ang konserbatoryo., Hinabol ng euopean hoopoe ang pusa., Binigyan ng parangal ng pangkat ang rogasyon., Ang mycenaen ay inanyayahan sa partido., Binigyan ako ng regalo ng bard., Ang taniman ng puno ay yari sa metal., Nasa mesa ang boot ng kongreso., Ang quoter ay inanyayahan sa partido., Binigyan ako ng regalo ng mga cheop., Hinabol ng palaka ang pusa., Ang bookend ay nasa mesa., Ang echolalia ay sa Sabado., Binigyan ng parangal ng pangkat ang negosyo., Ang lumalabag ay tumatakbo., Tumatakbo ang ulo ng tow., Ang parusang corporal ay matagumpay., Ang mga iroquois ay inanyayahan sa partido., Matagumpay ang pulso., Kinain ng maitim na kabayo ang pizza., Matatag ang gremonyo., Ang pansamantalang pagbabago ay inanyayahan sa partido., Ang saligang pagsasanay ay kinansela dahil sa ulan., Sumabog ang nobela., Nasa mesa ang cashmere., Ang shrike ay nasa bakuran., Ang myelograpiya ay tuwing Sabado., Nasiyahan ang mga tao sa elektronikong panlilinlang., Sumabog ang bangkong naimpok., Ang testee ang kumain ng pizza., Sumabog ang storker., Binigyan ako ng may - ari ng compress., Tuwang - tuwa ang mga tao sa katibayan., Ang pulutong ay nasiyahan sa kurbata ng kopa., Ang bahay na kinaingin ay itinatag noong 1990., Maligaya ang browser., Ang epekto ng coattails ay sa Sabado., Ang koponan ay nagbigay ng gantimpala sa pagsabog., Maligaya ang tlingit., Binigyan ng parangal ng pangkat ang solfege., Ang urceole ay matibay., Binigyan ako ng bantay - pintuang - daan ng isang regalo., Ang slit ay nawasak sa lindol., Nabali ang bintana dahil sa bahay., Tumatakbo ang batang lalaki., Ang mga boletus subvelitie ay sumasabog., Ang pundasyon ay kung Sabado., Ang manic-depressive ay nasa tindahan., Nabali ang bintana dahil sa tremella reticulata., Ang narthex ay yari sa metal., Dinadalaw ng mga tao ang lugar ng pangangaso., Nabali ang bintana dahil sa ingrowth., Ang maninisid ng perlas ay inanyayahan sa partido., Ang bituin ng flare ay yari sa metal., Ang standdown ay matagumpay., Ang afterburner ay sumasabog., Ang pitong-up ay matagumpay., Ang argonaut ay yari sa metal., Ang synthesist ay maligaya., Ang sporangiophore ay matibay., Nabali ang bintana dahil sa tagapagtanim., Binigyan ng bonus ng lupon ang departamento ng mga tauhan., Tumakbo ang sundalo., Tumatakbo ang mga ibong guinea., Naganap ang pakikipag-ugnayang palakasan., Hinabol ng alimangong fiddler ang pusa., Ang elimolismo ay kinansela dahil sa pag-ulan., Ang bitthead ay lumalago., Bini ...
# [[bintana],
#  [],
#  [gal],
#  [pangkat],
#  [bintana],
#  [resort],
#  [pagsubok],
#  [pagmomodelo],
#  [bintana],
#  [kapatid],
#  [pizza],
#  [bangin],
#  [meridyano],
#  [picket],
#  [hayop],
#  [bard],
#  [wika],
#  [takip],
#  [attendant],
#  [obserhista],
#  [bintana],
#  [pizza],
#  [bodega],
#  [lumaon],
#  [defender],
#  [knell],
#  [pandinig],
#  [austin],
#  [gladiator],
#  [upuan],
#  [pintor],
#  [alperes],
#  [ugat],
#  [masonerya],
#  [baseboard],
#  [magbubukid],
#  [larangan],
#  [pagsasanib],
#  [pizza],
#  [demagoguery],
#  [konserbatoryo],
#  [pusa],
#  [rogasyon],
#  [mycenaen],
#  [ako],
#  [taniman],
#  [boot],
#  [quoter],
#  [ako],
#  [pusa],
#  [bookend],
#  [echolalia],
#  [negosyo],
#  [lumalabag],
#  [ulo],
#  [parusang],
#  [iroquois],
#  [pulso],
#  [pizza],
#  [gremonyo],
#  [pagbabago],
#  [pagsasanay],
#  [nobela],
#  [cashmere],
#  [shrike],
#  [myelograpiya],
#  [tao],
#  [bangkong],
#  [kumain],
#  [storker],
#  [ako],
#  [tao],
#  [pulutong],
#  [bahay],
#  [browser],
#  [epekto],
#  [koponan],
#  [tlingit],
#  [solfege],
#  [urceole],
#  [ako],
#  [slit],
#  [bintana],
#  [lalaki],
#  [subvelitie],
#  [pundasyon],
#  [manic, -, depressive],
#  [bintana],
#  [narthex],
#  [lugar],
#  [bintana],
#  [maninisid],
#  [bituin],
#  [standdown],
#  [afterburner],
#  [pitong, -, up],
#  [argonaut],
#  [synthesist],
#  [sporangiophore],
#  [bintana],
#  [departamento],
#  [sundalo],
#  [guinea],
#  [palakasan],
#  [pusa],
#  [elimolismo],
#  [bitthead],
#  [ako],
#  [tao],
#  [pagkapukaw],
#  [tanawin],
#  [aaral],
#  [chinoiserie],
#  [borough],
#  [bag],
#  [estado, dagat],
#  [systematization],
#  [snood],
#  [pulutong],
#  [ako],
#  [letterman],
#  [koordinasyon],
#  [konsilyo],
#  [tahanan],
#  [lababo],
#  [paglalatag],
#  [paglaki],
#  [kalan],
#  [raft],
#  [kasuutan],
#  [resistor],
#  [bug],
#  [bintana],
#  [kumbinasyon],
#  [pagkasira],
#  [taong],
#  [leave],
#  [ako],
#  [asul],
#  [saxon],
#  [espasyong],
#  [sphinx],
#  [istasyon],
#  [rectifier],
#  [samahan],
#  [tao],
#  [cercaria],
#  [tuwalya],
#  [pinding],
#  [bintana],
#  [ahensiya],
#  [hukbong],
#  [alto],
#  [ako],
#  [corpuscle],
#  [heater],
#  [grupong],
#  [valentine],
#  [waldense],
#  [bola],
#  [crepe],
#  [ako],
#  [tumugon],
#  [kidnaper],
#  [kakampi],
#  [kumain],
#  [novena],
#  [abolisyonista],
#  [center],
#  [lalaki],
#  [ibon],
#  [pizza],
#  [bikaryo],
#  [pagsuway],
#  [kalye],
#  [tao],
#  [bintana],
#  [aposelene],
#  [bangkong],
#  [bintana],
#  [tagaawit],
#  [koromaster],
#  [tagalarawan],
#  [koordinado],
#  [pagdating],
#  [panginoon],
#  [langgam],
#  [sona],
#  [botang],
#  [decal],
#  [spaniel],
#  [arcaebacteria],
#  [panlabas],
#  [vouchere],
#  [buteonine],
#  [koponan],
#  [firebreak],
#  [bilog],
#  [ako],
#  [lugar],
#  [ahensiyang],
#  [ang, dagat],
#  [grupo],
#  [komisyong],
#  [ang, pag, -, iimbestiga],
#  [liwasan],
#  [ako],
#  [manlalakbay],
#  [ako],
#  [pantalan],
#  [balot],
#  [converter],
#  [rail],
#  [foxhound],
#  [pizza],
#  [kislap],
#  [akit],
#  [tao],
#  [tao],
#  [bakuran],
#  [liwanag],
#  [tagalibing],
#  [linya],
#  [ako],
#  [karagdagan],
#  [hardin],
#  [dokumentaryo],
#  [butas],
#  [sigaw],
#  [balbas],
#  [pederal],
#  [reflex],
#  [pulutong],
#  [bintana],
#  [ako],
#  [pagtahak],
#  [misogamista],
#  [casus],
#  [ikalawa],
#  [babaing],
#  [bag],
#  [linya],
#  [dapnia],
#  [gametoecium],
#  [teknolohiya],
#  [hilig],
#  [pad],
#  [hukay],
#  [pony, -, trekking],
#  [paradahan],
#  [alagang],
#  [udicator],
#  [lavalie],
#  [ako],
#  [pizza],
#  [pagkakatapon],
#  [pizza],
#  [ako],
#  [tenis],
#  [ako],
#  [katiwala],
#  [tao],
#  [dambana],
#  [pizza],
#  [sentro],
#  [lithophyte],
#  [self, -, organisasyon],
#  [ama],
#  [raffle],
#  [bonus],
#  [lupon],
#  [ako],
#  [ego],
#  [bintana],
#  [],
#  [isdang],
#  [existentialist],
#  [ang, scene, -, stealer],
#  [clip],
#  [pagdami],
#  [palakang],
#  [bintana],
#  [transaksyon],
#  [ako],
#  [ako],
#  [pandaraya],
#  [goalkeeper],
#  [tao],
#  [pizza],
#  [makintab],
#  [pamamahayag],
#  [bug],
#  [poster],
#  [tagalarawan],
#  [salat],
#  [pizza],
#  [jassid],
#  [couturier],
#  [bintana],
#  [mantrap],
#  [opisina],
#  [ako],
#  [nadir],
#  [alulusan],
#  [osteologo],
#  [kaliwa],
#  [bintana],
#  [pizza],
#  [trinidadian],
#  [bintana],
#  [],
#  [pagsasara],
#  [postdoc],
#  [bintana],
#  [sannup],
#  [sapin],
#  [oilcan],
#  [pagboto],
#  [pagpapalabas],
#  [telomere],
#  [paglapag],
#  [nagpapautang],
#  [alilang],
#  [negosyo],
#  [batching],
#  [nucleifier],
#  [labanan],
#  [pagiging],
#  [liga],
#  [pizza],
#  [sukat],
#  [franchise],
#  [excogitator],
#  [zero],
#  [gumagawa],
#  [bash],
#  [cockdler],
#  [episodyo],
#  [abbe],
#  [hitfaway],
#  [taluktok],
#  [palihim],
#  [croupier],
#  [tuklaw],
#  [zoroastrian],
#  [mixed, -, blood],
#  [sukat],
#  [kamera],
#  [gas],
#  [coach],
#  [niby],
#  [pizza],
#  [amo],
#  [likod],
#  [speleolohiya],
#  [shot],
#  [bakuran],
#  [lupon],
#  [tauhan],
#  [tagaguhit],
#  [tom],
#  [aaral],
#  [bolyum],
#  [daanan],
#  [foul],
#  [amag],
#  [sirena],
#  [charon],
#  [pizza],
#  [dako],
#  [pulutong],
#  [tablang],
#  [isohel],
#  [ketongin],
#  [bintana],
#  [pandaraya],
#  [napopoot],
#  [ako],
#  [pangkat],
#  [ako],
#  [taoiseach],
#  [tracker],
#  [pusa],
#  [pulutong],
#  [bintana],
#  [dalubwika],
#  [pusa],
#  [putbol],
#  [estado],
#  [pandaraya],
#  [ako],
#  [pagbagsak],
#  [dionysia],
#  [bintana],
#  [terrier],
#  [nasyonalisasyon],
#  [veld],
#  [nabob],
#  [sona],
#  [kanyon],
#  [bintana],
#  [tao],
#  [kasbah],
#  [aktibo],
#  [pulis],
#  [pizza],
#  [halchidhoma],
#  [bintana],
#  [laminasyon],
#  [paglalakad],
#  [],
#  [defestration],
#  [sumira],
#  [molehill],
#  [sarcosomataceae],
#  [pagtatagpo],
#  [bintana],
#  [pusa],
#  [agronomo],
#  [pizza],
#  [roifer],
#  [base],
#  [algerian],
#  [bintana],
#  [lobbyist],
#  [matron],
#  [zone],
#  [bomba],
#  [coscoroba],
#  [stub],
#  [brahui],
#  [goldfield],
#  [],
#  [bintana],
#  [ako],
#  [kagawaran],
#  [basura],
#  [massif],
#  [ratline],
#  [pagpapangalan],
#  [alon],
#  [subtropiko],
#  [nabrain],
#  [pag, -, alis],
#  [antropometriya],
#  [drawingback],
#  [tao],
#  [karoft],
#  [tangway],
#  [pusa],
#  [pundasyon],
#  [pulutong],
#  [],
#  [tao],
#  [koponan],
#  [puwang],
#  [negosyo],
#  [pulutong],
#  [ninuno],
#  [ang, may, -, akda, -, occupier],
#  [europe],
#  [ako],
#  [pusa],
#  [marino],
#  [pizza],
#  [indise],
#  [taguan],
#  [lhasa],
#  [reliterate],
#  [pizza],
#  [vroom],
#  [adagio],
#  [kumakain],
#  [freestyle],
#  [mestizo],
#  [weurer],
#  [sporocarp],
#  [pulutong],
#  [paboreal],
#  [ako],
#  [sentro],
#  [karamihan],
#  [sangkapat],
#  [kanser],
#  [semite],
#  [yelo],
#  [botaniko],
#  [umaakyat],
#  [utos],
#  [kuryente],
#  [butas],
#  [tagagawa],
#  [escastingrace],
#  [pagbibisikleta],
#  [kayariang],
#  [ako],
#  [scout],
#  [giro],
#  [pagtanggap],
#  [nagbabayad],
#  [bilang],
#  [pulutong],
#  [bintana],
#  [institusyon],
#  [dahon],
#  [bintana],
#  [astrophyton],
#  [legimasyon],
#  [konsultasyon],
#  [maninila],
#  [koponan],
#  [kasagsagan],
#  [millenarian],
#  [starlet],
#  [mass],
#  [suzerainty],
#  [butas],
#  [tao],
#  [ako],
#  [sektor],
#  [henry],
#  [pagpapaunlad],
#  [bintana],
#  [linge],
#  [lata],
#  [ako],
#  [tolda],
#  [pizza],
#  [pagdalaw],
#  [anggulo],
#  [may],
#  [bintana],
#  [salamander],
#  [centroid],
#  [pizza],
#  [flowerbed],
#  [servo],
#  [comptrollership],
#  [bakteriophage],
#  [manunudyo],
#  [talaba],
#  [barnacle],
#  [tobagonian],
#  [palafoot],
#  [ratipikasyon],
#  [magisonette],
#  [indonesian],
#  [bintana],
#  [ulo],
#  [pizza],
#  [humahawak],
#  [bintana],
#  [bintana],
#  [mangangaso],
#  [isport],
#  [apoy],
#  [ako],
#  [taong],
#  [bintana],
#  [lehislatura],
#  [gas],
#  [parol],
#  [biro],
#  [gin],
#  [himig],
#  [dogleg],
#  [bintana],
#  [fiance],
#  [ako],
#  [springtide],
#  [liberian],
#  [bola],
#  [bata],
#  [sako],
#  [pagbaba],
#  [kosmetologo],
#  [bintana],
#  [pizza],
#  [espasyong],
#  [tao],
#  [buhay],
#  [plais],
#  [bintana],
#  [bomb],
#  [bintana],
#  [iisangstick],
#  [quetzal],
#  [palikpik],
#  [mansanas],
#  [ministro],
#  [tagapanayam],
#  [stand],
#  [ako],
#  [gawain],
#  [ako],
#  [nagpautang],
#  [pensioner],
#  [slingshot],
#  [ilalim],
#  [kawing],
#  [tagalista],
#  [woodhewer],
#  [plais],
#  [gang],
#  [viireo],
#  [lutuin],
#  [tao],
#  [kabayong],
#  [ang, usbong-'em, -, up],
#  [varsity],
#  [archiannelid],
#  [simbolikong],
#  [bintana],
#  [koreo],
#  [gingham],
#  [pagkalantad],
#  [tungus],
#  [puff],
#  [lithomancer],
#  [plato],
#  [katarungan],
#  [poodle],
#  [submarino],
#  [articulator],
#  [kalihim],
#  [pizza],
#  [ako],
#  [borzoi],
#  [seminarian],
#  [ako],
#  [krisis],
#  [ako, ng],
#  [terno],
#  [german],
#  [jejunostomiya],
#  [pulutong],
#  [buhok],
#  [pagiging],
#  [pizza],
#  [damo],
#  [beecket],
#  [pizza],
#  [cranny],
#  [pagkasunog],
#  [resolusyon],
#  [pizza],
#  [ako],
#  [pulutong],
#  [pamilihan],
#  [koponan],
#  [ako],
#  [crottle],
#  [magulang],
#  [aerophile],
#  [tibagan],
#  [sangay],
#  [lasenggong],
#  [welterweight],
#  [tagasaulo],
#  [larangan],
#  [pabigat],
#  [ako],
#  [tangway],
#  [apoy],
#  [limey],
#  [pormalidad],
#  [salamander],
#  [],
#  [bintana],
#  [pagsamo],
#  [paglalaro],
#  [bulwagan],
#  [bintana],
#  [tumututol],
#  [tumututol],
#  [split],
#  [zen],
#  [bintana],
#  [ako],
#  [tao],
#  [kalawakan],
#  [pangkat],
#  [ayon],
#  [larong],
#  [pizza],
#  [bagay],
#  [radyo],
#  [babaing],
#  [pagtatanghal],
#  [cockfighting],
#  [bintana],
#  [operasyon],
#  [pulutong],
#  [copilot],
#  [ako],
#  [henyo],
#  [kagawaran],
#  [bintana],
#  [linya],
#  [tagapamahayag],
#  [idolo],
#  [kumandante],
#  [aso],
#  [],
#  [kabkáb],
#  [mananayaw],
#  [cherrystone],
#  [subnormal],
#  [negosyo],
#  [espesyalisasyon],
#  [tagapagpala],
#  [-, kabayohan],
#  [damit],
#  [pahayagan],
#  [magnitud],
#  [bintana],
#  [salamander],
#  [magnanakaw],
#  [kaaliwan],
#  [pagpatay],
#  [therapist],
#  [paghinto],
#  [ampon, -, ina],
#  [parol],
#  [broadcast],
#  [popgun],
#  [pizza],
#  [theosophist],
#  [ako],
#  [pamigkis],
#  [pulutong],
#  [biyak],
#  [aralan],
#  [modalidad],
#  [schnauzer],
#  [scriptwriter],
#  [tripper],
#  [claustrophobe],
#  [amplipikasyon],
#  [bintana],
#  [samaritano],
#  [nagwagi],
#  [strawworm],
#  [orkestra],
#  [tao],
#  [komite],
#  [kapangalan],
#  [denominasyon],
#  [lupon],
#  [substrate],
#  [bintana],
#  [bintana],
#  [panlamig],
#  [oriole],
#  [pulutong],
#  [lubid],
#  [kagandahan],
#  [chrotch],
#  [awseer],
#  [labanan],
#  [ako],
#  [kendi],
#  [ako],
#  [tao],
#  [american],
#  [lint],
#  [gumagamit],
#  [palitan],
#  [falcon],
#  [odalisque],
#  [antefix],
#  [tagagaod],
#  [kasakdalan],
#  [kasama],
#  [sihay],
#  [lakas],
#  [pusa],
#  [pantubig],
#  [anggulo],
#  [typification],
#  [kamay],
#  [tahi],
#  [beetle],
#  [bintana],
#  [pizza],
#  [palabas],
#  [ash],
#  [bumbero],
#  [pagpapaganda],
#  [aalis],
#  [asobane],
#  [weyter],
#  [korporasyon],
#  [gyneolatry],
#  [pagputok],
#  [pagsulong],
#  [Ang, may, -, akda],
#  [pangkat],
#  [sanipe],
#  [paglakad],
#  [pagtanggi],
#  [pagpapaganda],
#  [anggulo],
#  [polen],
#  [optimista],
#  [snowboarding],
#  [dais],
#  [bakod],
#  [gaala],
#  [pagiging],
#  [bibi],
#  [erie],
#  [pamayanan],
#  [ulo],
#  [kriminalisasyon],
#  [ako],
#  [kuko],
#  [posisyon],
#  [ako],
#  [laruang],
#  [pagsusuri],
#  [bintana],
#  [ang, drive, -, in],
#  [ako],
#  [korona],
#  [revoke],
#  [hiwa],
#  [catholic],
#  [bib],
#  [bonodiggle],
#  [bintana],
#  [tao],
#  [bintana],
#  [bintana],
#  [ninja],
#  [bunton],
#  [pagsasagawa],
#  [ako],
#  [school],
#  [insenso],
#  [addressee],
#  [bintana],
#  [takbo],
#  [presbitero],
#  [coursework],
#  [pulutong],
#  [komunikasyong],
#  [agnate],
#  [toastmaster],
#  [dog],
#  [],
#  [balinghoy],
#  [bintana],
#  [ako],
#  [pusa],
#  [napopoot],
#  [samite],
#  [club],
#  [toucanet],
#  [vizsla],
#  [linya],
#  [pagano],
#  [manunubos],
#  [],
#  [kartel],
#  [salamannder],
#  [ironmongery],
#  [bilis],
#  [bintana],
#  [market],
#  [ako],
#  [manlalaro],
#  [ako],
#  [baluktot],
#  [kidnaper],
#  [tom],
#  [akademya],
#  [set],
#  [philatelist],
#  [disiplina],
#  [pulutong],
#  [modeler],
#  [ako],
#  [ako],
#  [tagahila],
#  [impulsive],
#  [maze],
#  [ako],
#  [swot],
#  [piyanista],
#  [ako],
#  [pulutong],
#  [ako],
#  [jerboa],
#  [ordeng],
#  [pizza],
#  [kawad],
#  [pagsasanay],
#  [plantlet],
#  [guhit],
#  [bintana],
#  [pulutong],
#  [bilang],
#  [ako],
#  [pulutong],
#  [lobe],
#  [tunika],
#  [pagkontrol],
#  [pagbabago],
#  [paghalili],
#  [panakot],
#  [pagputok],
#  [may],
#  [bintana],
#  [pambubugbog],
#  [kuhol],
#  [nondescript],
#  [stock],
#  [bintana],
#  [variet],
#  [pagpapalayas],
#  [tagalikom],
#  [bintana],
#  [tagapalo],
#  [kapaligiran],
#  [ako],
#  [hangganan],
#  [pampolitika],
#  [pulutong],
#  [bumbero],
#  [tagatunaw],
#  [lunas],
#  [ako],
#  [ibabaw],
#  [tagagawa],
#  [pahayagan],
#  [centering],
#  [ironmongery],
#  [pulutong],
#  [pagrerelaks],
#  [parvi],
#  [communit],
#  [ekwasyon],
#  [homeopath],
#  [caravanning],
#  [sorbian],
#  [],
#  [pagod],
#  [single, -, to],
#  [pases],
#  [pugo],
#  [tao],
#  [walk, -, in],
#  [afrikaner],
#  [suffragan],
#  [pangkat],
#  [sapatos],
#  [labyrinthodont],
#  [anak],
#  [pizza],
#  [terno],
#  [pinakamahaba],
#  [panginoon],
#  [gastroenterologo],
#  [ako],
#  [buhok],
#  [paramedik],
#  [kompetisyon],
#  [pagiging],
#  [isa],
#  [ako],
#  [pusa],
#  [shabu],
#  [koponan],
#  [pizza],
#  [pusa],
#  [dyspeptic],
#  [paliguan],
#  [cloverleaf],
#  [monocarp],
#  [baka],
#  [boson],
#  [tala],
#  [marline],
#  [ang, z, -, axis],
#  [wheel],
#  [pusa],
#  [ako],
#  [apendicle],
#  [slot],
#  [darter],
#  [pagsisiwalat],
#  [matanda],
#  [helm],
#  [pagsugod],
#  [negosyo],
#  [ako],
#  [upa],
#  [australian],
#  [sandbar]]

# %%
# real implementation
tl_df = pd.read_csv("translated_helsinki.csv").drop(columns=['Unnamed: 0'])
to_tl_dp = tl_df['translated_en_helsinki'].values.tolist()

nsubj_from_en_tl_doc = calamancy_dp(to_tl_dp)
nsubj_from_en_tl_list = docList_to_nsubjList(nsubj_from_en_tl_doc)
tl_df['nsubj_from_helsinki_en_tl'] = nsubj_from_en_tl_list
tl_df.to_csv("translated_helsinki_with_tl_dp.csv")
tl_df
# Out:
# calamancy dependecy parsing - parsed: 64 ETA: 0:10:52.672591
# calamancy dependecy parsing - parsed: 192 ETA: 0:19:47.694534
# calamancy dependecy parsing - parsed: 320 ETA: 0:29:57.467794
# calamancy dependecy parsing - parsed: 448 ETA: 0:40:02.665720
# calamancy dependecy parsing - parsed: 576 ETA: 0:50:05.988974
# calamancy dependecy parsing - parsed: 704 ETA: 0:49:21.185853
# calamancy dependecy parsing - parsed: 832 ETA: 0:49:19.056384
# calamancy dependecy parsing - parsed: 960 ETA: 0:49:16.730257
# calamancy dependecy parsing - parsed: 1088 ETA: 0:48:40.008590
# calamancy dependecy parsing - parsed: 1216 ETA: 0:48:49.073288
# calamancy dependecy parsing - parsed: 1344 ETA: 0:48:42.736893
# calamancy dependecy parsing - parsed: 1472 ETA: 0:49:50.447170
# calamancy dependecy parsing - parsed: 1600 ETA: 0:49:14.290775
# calamancy dependecy parsing - parsed: 1728 ETA: 0:49:39.044348
# calamancy dependecy parsing - parsed: 1856 ETA: 0:49:30.811086
# calamancy dependecy parsing - parsed: 1984 ETA: 0:49:22.034287
# calamancy dependecy parsing - parsed: 2112 ETA: 0:48:48.309133
# calamancy dependecy parsing - parsed: 2240 ETA: 0:48:12.142330
# calamancy dependecy parsing - parsed: 2368 ETA: 0:46:46.573399
# calamancy dependecy parsing - parsed: 2496 ETA: 0:45:12.808100
# calamancy dependecy parsing - parsed: 2624 ETA: 0:44:25.789224
# calamancy dependecy parsing - parsed: 2752 ETA: 0:43:55.524078
# calamancy dependecy parsing - parsed: 2880 ETA: 0:43:49.841194
# calamancy dependecy parsing - parsed: 3008 ETA: 0:44:10.229583
# calamancy dependecy parsing - parsed: 3136 ETA: 0:43:46.351774
# calamancy dependecy parsing - parsed: 3264 ETA: 0:43:41.175803
# calamancy dependecy parsing - parsed: 3392 ETA: 0:44:04.183794
# calamancy dependecy parsing - parsed: 3520 ETA: 0:44:15.767556
# calamancy dependecy parsing - parsed: 3648 ETA: 0:44:30.703092
# calamancy dependecy parsing - parsed: 3776 ETA: 0:44:47.016105
# calamancy dependecy parsing - parsed: 3904 ETA: 0:45:09.227689
# calamancy dependecy parsing - parsed: 4032 ETA: 0:43:29.961938
# calamancy dependecy parsing - parsed: 4160 ETA: 0:44:55.070002
# calamancy dependecy parsing - parsed: 4288 ETA: 0:44:04.604610
# calamancy dependecy parsing - parsed: 4416 ETA: 0:44:18.882182
# calamancy dependecy parsing - parsed: 4544 ETA: 0:44:50.165274
# calamancy dependecy parsing - parsed: 4672 ETA: 0:46:08.367110
# calamancy dependecy parsing - parsed: 4800 ETA: 0:44:06.162724
# calamancy dependecy parsing - parsed: 4928 ETA: 0:44:46.929058
# calamancy dependecy parsing - parsed: 5056 ETA: 0:44:53.724833
# calamancy dependecy parsing - parsed: 5184 ETA: 0:43:53.048841
# calamancy dependecy parsing - parsed: 5312 ETA: 0:43:27.488971
# calamancy dependecy parsing - parsed: 5440 ETA: 0:42:54.067921
# calamancy dependecy parsing - parsed: 5568 ETA: 0:42:05.039048
# calamancy dependecy parsing - parsed: 5696 ETA: 0:43:35.123908
# calamancy dependecy parsing - parsed: 5824 ETA: 0:43:21.076870
# calamancy dependecy parsing - parsed: 5952 ETA: 0:43:37.359817
# calamancy dependecy parsing - parsed: 6080 ETA: 0:44:32.043893
# calamancy dependecy parsing - parsed: 6208 ETA: 0:45:23.183368
# calamancy dependecy parsing - parsed: 6336 ETA: 0:45:16.083343
# calamancy dependecy parsing - parsed: 6464 ETA: 0:47:02.893373
# calamancy dependecy parsing - parsed: 6592 ETA: 0:48:23.812035
# calamancy dependecy parsing - parsed: 6720 ETA: 0:50:35.117031
# calamancy dependecy parsing - parsed: 6848 ETA: 0:51:07.045165
# calamancy dependecy parsing - parsed: 6976 ETA: 0:51:09.187842
# calamancy dependecy parsing - parsed: 7104 ETA: 0:51:00.726773
# calamancy dependecy parsing - parsed: 7232 ETA: 0:51:01.015978
# calamancy dependecy parsing - parsed: 7360 ETA: 0:49:37.152922
# calamancy dependecy parsing - parsed: 7488 ETA: 0:49:48.151290
# calamancy dependecy parsing - parsed: 7616 ETA: 0:49:35.966762
# calamancy dependecy parsing - parsed: 7744 ETA: 0:48:36.329234
# calamancy dependecy parsing - parsed: 7872 ETA: 0:48:22.787159
# calamancy dependecy parsing - parsed: 8000 ETA: 0:49:12.160698
# calamancy dependecy parsing - parsed: 8128 ETA: 0:49:07.439109
# calamancy dependecy parsing - parsed: 8256 ETA: 0:49:03.242965
# calamancy dependecy parsing - parsed: 8384 ETA: 0:49:44.302457
# calamancy dependecy parsing - parsed: 8512 ETA: 0:50:16.886083
# calamancy dependecy parsing - parsed: 8640 ETA: 0:50:06.342102
# calamancy dependecy parsing - parsed: 8768 ETA: 0:50:48.747246
# calamancy dependecy parsing - parsed: 8896 ETA: 0:51:06.418787
# calamancy dependecy parsing - parsed: 9024 ETA: 0:50:39.706957
# calamancy dependecy parsing - parsed: 9152 ETA: 0:50:53.269001
# calamancy dependecy parsing - parsed: 9280 ETA: 0:50:59.924794
# calamancy dependecy parsing - parsed: 9408 ETA: 0:50:03.402244
# calamancy dependecy parsing - parsed: 9536 ETA: 0:49:00.882145
# calamancy dependecy parsing - parsed: 9664 ETA: 0:49:10.856409
# calamancy dependecy parsing - parsed: 9792 ETA: 0:47:35.337980
# calamancy dependecy parsing - parsed: 9920 ETA: 0:47:16.773082
# calamancy dependecy parsing - parsed: 10048 ETA: 0:47:34.989207
# calamancy dependecy parsing - parsed: 10176 ETA: 0:47:31.551995
# calamancy dependecy parsing - parsed: 10304 ETA: 0:48:02.770498
# calamancy dependecy parsing - parsed: 10432 ETA: 0:48:08.804628
# calamancy dependecy parsing - parsed: 10560 ETA: 0:48:27.886682
# calamancy dependecy parsing - parsed: 10688 ETA: 0:48:23.880888
# calamancy dependecy parsing - parsed: 10816 ETA: 0:48:29.450544
# calamancy dependecy parsing - parsed: 10944 ETA: 0:47:34.064612
# calamancy dependecy parsing - parsed: 11072 ETA: 0:47:02.449259
# calamancy dependecy parsing - parsed: 11200 ETA: 0:46:57.337556
# calamancy dependecy parsing - parsed: 11328 ETA: 0:46:19.605254
# calamancy dependecy parsing - parsed: 11456 ETA: 0:46:08.996074
# calamancy dependecy parsing - parsed: 11584 ETA: 0:45:54.165808
# calamancy dependecy parsing - parsed: 11712 ETA: 0:46:43.831255
# calamancy dependecy parsing - parsed: 11840 ETA: 0:46:08.953925
# calamancy dependecy parsing - parsed: 11968 ETA: 0:47:02.133589
# calamancy dependecy parsing - parsed: 12096 ETA: 0:47:06.391042
# calamancy dependecy parsing - parsed: 12224 ETA: 0:47:43.125228
# calamancy dependecy parsing - parsed: 12352 ETA: 0:46:41.902408
# calamancy dependecy parsing - parsed: 12480 ETA: 0:46:20.151673
# calamancy dependecy parsing - parsed: 12608 ETA: 0:45:27.058144
# calamancy dependecy parsing - parsed: 12736 ETA: 0:45:43.300812
# calamancy dependecy parsing - parsed: 12864 ETA: 0:45:50.775331
# calamancy dependecy parsing - parsed: 12992 ETA: 0:46:21.530575
# calamancy dependecy parsing - parsed: 13120 ETA: 0:46:17.847383
# calamancy dependecy parsing - parsed: 13248 ETA: 0:46:53.488042
# calamancy dependecy parsing - parsed: 13376 ETA: 0:46:59.691544
# calamancy dependecy parsing - parsed: 13504 ETA: 0:46:56.390483
# calamancy dependecy parsing - parsed: 13632 ETA: 0:47:49.004598
# calamancy dependecy parsing - parsed: 13760 ETA: 0:47:01.982837
# calamancy dependecy parsing - parsed: 13888 ETA: 0:46:25.482909
# calamancy dependecy parsing - parsed: 14016 ETA: 0:46:04.196521
# calamancy dependecy parsing - parsed: 14144 ETA: 0:45:56.282766
# calamancy dependecy parsing - parsed: 14272 ETA: 0:45:43.995173
# calamancy dependecy parsing - parsed: 14400 ETA: 0:46:47.744419
# calamancy dependecy parsing - parsed: 14528 ETA: 0:47:26.729611
# calamancy dependecy parsing - parsed: 14656 ETA: 0:47:12.394625
# calamancy dependecy parsing - parsed: 14784 ETA: 0:46:22.675916
# calamancy dependecy parsing - parsed: 14912 ETA: 0:45:38.597125
# calamancy dependecy parsing - parsed: 15040 ETA: 0:45:36.198006
# calamancy dependecy parsing - parsed: 15168 ETA: 0:46:32.251102
# calamancy dependecy parsing - parsed: 15296 ETA: 0:47:55.912196
# calamancy dependecy parsing - parsed: 15424 ETA: 0:47:24.696672
# calamancy dependecy parsing - parsed: 15552 ETA: 0:46:38.642308
# calamancy dependecy parsing - parsed: 15680 ETA: 0:44:52.213169
# calamancy dependecy parsing - parsed: 15808 ETA: 0:42:25.845069
# calamancy dependecy parsing - parsed: 15936 ETA: 0:40:40.067121
# calamancy dependecy parsing - parsed: 16064 ETA: 0:41:30.288485
# calamancy dependecy parsing - parsed: 16192 ETA: 0:41:24.236994
# calamancy dependecy parsing - parsed: 16320 ETA: 0:42:06.348395
# calamancy dependecy parsing - parsed: 16448 ETA: 0:42:24.385767
# calamancy dependecy parsing - parsed: 16576 ETA: 0:42:48.739716
# calamancy dependecy parsing - parsed: 16704 ETA: 0:43:21.828957
# calamancy dependecy parsing - parsed: 16832 ETA: 0:44:59.420950
# calamancy dependecy parsing - parsed: 16960 ETA: 0:46:39.246987
# calamancy dependecy parsing - parsed: 17088 ETA: 0:46:45.829930
# calamancy dependecy parsing - parsed: 17216 ETA: 0:46:07.015484
# calamancy dependecy parsing - parsed: 17344 ETA: 0:44:56.106922
# calamancy dependecy parsing - parsed: 17472 ETA: 0:43:39.646832
# calamancy dependecy parsing - parsed: 17600 ETA: 0:43:17.515012
# calamancy dependecy parsing - parsed: 17728 ETA: 0:43:20.017411
# calamancy dependecy parsing - parsed: 17856 ETA: 0:43:54.815698
# calamancy dependecy parsing - parsed: 17984 ETA: 0:44:43.183916
# calamancy dependecy parsing - parsed: 18112 ETA: 0:44:50.875885
# calamancy dependecy parsing - parsed: 18240 ETA: 0:44:05.910991
# calamancy dependecy parsing - parsed: 18368 ETA: 0:43:40.294555
# calamancy dependecy parsing - parsed: 18496 ETA: 0:44:07.484620
# calamancy dependecy parsing - parsed: 18624 ETA: 0:43:59.414464
# calamancy dependecy parsing - parsed: 18752 ETA: 0:44:44.168250
# calamancy dependecy parsing - parsed: 18880 ETA: 0:44:47.400076
# calamancy dependecy parsing - parsed: 19008 ETA: 0:46:21.789663
# calamancy dependecy parsing - parsed: 19136 ETA: 0:45:57.092126
# calamancy dependecy parsing - parsed: 19264 ETA: 0:46:01.089416
# calamancy dependecy parsing - parsed: 19392 ETA: 0:46:40.527014
# calamancy dependecy parsing - parsed: 19520 ETA: 0:46:41.850330
# calamancy dependecy parsing - parsed: 19648 ETA: 0:46:04.251286
# calamancy dependecy parsing - parsed: 19776 ETA: 0:46:50.613692
# calamancy dependecy parsing - parsed: 19904 ETA: 0:46:52.879138
# calamancy dependecy parsing - parsed: 20032 ETA: 0:46:29.666861
# calamancy dependecy parsing - parsed: 20160 ETA: 0:45:55.596438
# calamancy dependecy parsing - parsed: 20288 ETA: 0:45:09.680819
# calamancy dependecy parsing - parsed: 20416 ETA: 0:43:30.403336
# calamancy dependecy parsing - parsed: 20544 ETA: 0:43:20.902961
# calamancy dependecy parsing - parsed: 20672 ETA: 0:43:04.586325
# calamancy dependecy parsing - parsed: 20800 ETA: 0:44:20.863446
# calamancy dependecy parsing - parsed: 20928 ETA: 0:44:50.910506
# calamancy dependecy parsing - parsed: 21056 ETA: 0:46:35.323018
# calamancy dependecy parsing - parsed: 21184 ETA: 0:46:42.534112
# calamancy dependecy parsing - parsed: 21312 ETA: 0:46:57.356890
# calamancy dependecy parsing - parsed: 21440 ETA: 0:46:05.305447
# calamancy dependecy parsing - parsed: 21568 ETA: 0:46:18.823062
# calamancy dependecy parsing - parsed: 21696 ETA: 0:45:22.565840
# calamancy dependecy parsing - parsed: 21824 ETA: 0:45:08.413295
# calamancy dependecy parsing - parsed: 21952 ETA: 0:43:32.428910
# calamancy dependecy parsing - parsed: 22080 ETA: 0:43:58.125857
# calamancy dependecy parsing - parsed: 22208 ETA: 0:43:19.764745
# calamancy dependecy parsing - parsed: 22336 ETA: 0:43:42.195300
# calamancy dependecy parsing - parsed: 22464 ETA: 0:42:52.348758
# calamancy dependecy parsing - parsed: 22592 ETA: 0:43:24.471476
# calamancy dependecy parsing - parsed: 22720 ETA: 0:42:52.218925
# calamancy dependecy parsing - parsed: 22848 ETA: 0:43:00.990982
# calamancy dependecy parsing - parsed: 22976 ETA: 0:42:21.436770
# calamancy dependecy parsing - parsed: 23104 ETA: 0:41:59.677673
# calamancy dependecy parsing - parsed: 23232 ETA: 0:41:50.923550
# calamancy dependecy parsing - parsed: 23360 ETA: 0:41:45.508486
# calamancy dependecy parsing - parsed: 23488 ETA: 0:41:14.501684
# calamancy dependecy parsing - parsed: 23616 ETA: 0:41:21.950917
# calamancy dependecy parsing - parsed: 23744 ETA: 0:42:55.689149
# calamancy dependecy parsing - parsed: 23872 ETA: 0:43:57.479827
# calamancy dependecy parsing - parsed: 24000 ETA: 0:44:20.037732
# calamancy dependecy parsing - parsed: 24128 ETA: 0:44:26.432045
# calamancy dependecy parsing - parsed: 24256 ETA: 0:44:39.803850
# calamancy dependecy parsing - parsed: 24384 ETA: 0:44:10.244553
# calamancy dependecy parsing - parsed: 24512 ETA: 0:42:47.457202
# calamancy dependecy parsing - parsed: 24640 ETA: 0:41:45.649321
# calamancy dependecy parsing - parsed: 24768 ETA: 0:42:21.879381
# calamancy dependecy parsing - parsed: 24896 ETA: 0:42:12.676307
# calamancy dependecy parsing - parsed: 25024 ETA: 0:41:27.704496
# calamancy dependecy parsing - parsed: 25152 ETA: 0:42:10.360978
# calamancy dependecy parsing - parsed: 25280 ETA: 0:41:54.238791
# calamancy dependecy parsing - parsed: 25408 ETA: 0:42:23.172614
# calamancy dependecy parsing - parsed: 25536 ETA: 0:41:23.487633
# calamancy dependecy parsing - parsed: 25664 ETA: 0:41:20.683300
# calamancy dependecy parsing - parsed: 25792 ETA: 0:40:30.837362
# calamancy dependecy parsing - parsed: 25920 ETA: 0:39:55.764219
# calamancy dependecy parsing - parsed: 26048 ETA: 0:38:15.005877
# calamancy dependecy parsing - parsed: 26176 ETA: 0:38:17.920362
# calamancy dependecy parsing - parsed: 26304 ETA: 0:38:14.154367
# calamancy dependecy parsing - parsed: 26432 ETA: 0:37:53.101618
# calamancy dependecy parsing - parsed: 26560 ETA: 0:39:44.841280
# calamancy dependecy parsing - parsed: 26688 ETA: 0:40:42.623458
# calamancy dependecy parsing - parsed: 26816 ETA: 0:41:26.131243
# calamancy dependecy parsing - parsed: 26944 ETA: 0:40:52.768185
# calamancy dependecy parsing - parsed: 27072 ETA: 0:41:43.829705
# calamancy dependecy parsing - parsed: 27200 ETA: 0:40:23.630669
# calamancy dependecy parsing - parsed: 27328 ETA: 0:39:43.395191
# calamancy dependecy parsing - parsed: 27456 ETA: 0:39:42.993772
# calamancy dependecy parsing - parsed: 27584 ETA: 0:40:57.495604
# calamancy dependecy parsing - parsed: 27712 ETA: 0:40:37.946124
# calamancy dependecy parsing - parsed: 27840 ETA: 0:41:43.613212
# calamancy dependecy parsing - parsed: 27968 ETA: 0:41:42.314682
# calamancy dependecy parsing - parsed: 28096 ETA: 0:43:38.206170
# calamancy dependecy parsing - parsed: 28224 ETA: 0:43:11.359549
# calamancy dependecy parsing - parsed: 28352 ETA: 0:43:07.990796
# calamancy dependecy parsing - parsed: 28480 ETA: 0:42:01.360846
# calamancy dependecy parsing - parsed: 28608 ETA: 0:41:50.376173
# calamancy dependecy parsing - parsed: 28736 ETA: 0:39:19.326778
# calamancy dependecy parsing - parsed: 28864 ETA: 0:39:40.996185
# calamancy dependecy parsing - parsed: 28992 ETA: 0:39:34.968050
# calamancy dependecy parsing - parsed: 29120 ETA: 0:40:01.132704
# calamancy dependecy parsing - parsed: 29248 ETA: 0:40:47.151767
# calamancy dependecy parsing - parsed: 29376 ETA: 0:41:23.590907
# calamancy dependecy parsing - parsed: 29504 ETA: 0:41:26.852499
# calamancy dependecy parsing - parsed: 29632 ETA: 0:41:29.981107
# calamancy dependecy parsing - parsed: 29760 ETA: 0:41:27.902832
# calamancy dependecy parsing - parsed: 29888 ETA: 0:40:22.683229
# calamancy dependecy parsing - parsed: 30016 ETA: 0:39:43.358167
# calamancy dependecy parsing - parsed: 30144 ETA: 0:39:40.838875
# calamancy dependecy parsing - parsed: 30272 ETA: 0:39:52.655125
# calamancy dependecy parsing - parsed: 30400 ETA: 0:40:03.689441
# calamancy dependecy parsing - parsed: 30528 ETA: 0:40:07.433245
# calamancy dependecy parsing - parsed: 30656 ETA: 0:39:48.982645
# calamancy dependecy parsing - parsed: 30784 ETA: 0:39:49.729824
# calamancy dependecy parsing - parsed: 30912 ETA: 0:40:01.605985
# calamancy dependecy parsing - parsed: 31040 ETA: 0:39:52.688494
# calamancy dependecy parsing - parsed: 31168 ETA: 0:42:41.584270
# calamancy dependecy parsing - parsed: 31296 ETA: 0:43:36.150403
# calamancy dependecy parsing - parsed: 31424 ETA: 0:43:43.596152
# calamancy dependecy parsing - parsed: 31552 ETA: 0:43:09.062509
# calamancy dependecy parsing - parsed: 31680 ETA: 0:43:13.877790
# calamancy dependecy parsing - parsed: 31808 ETA: 0:40:58.058537
# calamancy dependecy parsing - parsed: 31936 ETA: 0:42:25.145356
# calamancy dependecy parsing - parsed: 32064 ETA: 0:41:32.294836
# calamancy dependecy parsing - parsed: 32192 ETA: 0:42:25.981115
# calamancy dependecy parsing - parsed: 32320 ETA: 0:41:40.845326
# calamancy dependecy parsing - parsed: 32448 ETA: 0:41:28.362865
# calamancy dependecy parsing - parsed: 32576 ETA: 0:40:22.697528
# calamancy dependecy parsing - parsed: 32704 ETA: 0:41:23.873015
# calamancy dependecy parsing - parsed: 32832 ETA: 0:41:00.954531
# calamancy dependecy parsing - parsed: 32960 ETA: 0:41:42.169346
# calamancy dependecy parsing - parsed: 33088 ETA: 0:42:25.486970
# calamancy dependecy parsing - parsed: 33216 ETA: 0:41:24.157503
# calamancy dependecy parsing - parsed: 33344 ETA: 0:41:20.230481
# calamancy dependecy parsing - parsed: 33472 ETA: 0:42:17.495248
# calamancy dependecy parsing - parsed: 33600 ETA: 0:41:35.019043
# calamancy dependecy parsing - parsed: 33728 ETA: 0:40:40.444629
# calamancy dependecy parsing - parsed: 33856 ETA: 0:40:09.131137
# calamancy dependecy parsing - parsed: 33984 ETA: 0:38:29.861525
# calamancy dependecy parsing - parsed: 34112 ETA: 0:36:48.654618
# calamancy dependecy parsing - parsed: 34240 ETA: 0:37:15.865516
# calamancy dependecy parsing - parsed: 34368 ETA: 0:37:12.583954
# calamancy dependecy parsing - parsed: 34496 ETA: 0:37:43.081368
# calamancy dependecy parsing - parsed: 34624 ETA: 0:38:14.289980
# calamancy dependecy parsing - parsed: 34752 ETA: 0:37:52.887066
# calamancy dependecy parsing - parsed: 34880 ETA: 0:37:52.172211
# calamancy dependecy parsing - parsed: 35008 ETA: 0:38:02.291928
# calamancy dependecy parsing - parsed: 35136 ETA: 0:38:03.461489
# calamancy dependecy parsing - parsed: 35264 ETA: 0:38:06.394951
# calamancy dependecy parsing - parsed: 35392 ETA: 0:39:23.581046
# calamancy dependecy parsing - parsed: 35520 ETA: 0:39:37.334863
# calamancy dependecy parsing - parsed: 35648 ETA: 0:39:36.571771
# calamancy dependecy parsing - parsed: 35776 ETA: 0:40:24.372652
# calamancy dependecy parsing - parsed: 35904 ETA: 0:39:39.813384
# calamancy dependecy parsing - parsed: 36032 ETA: 0:38:38.108816
# calamancy dependecy parsing - parsed: 36160 ETA: 0:38:34.497336
# calamancy dependecy parsing - parsed: 36288 ETA: 0:37:58.588283
# calamancy dependecy parsing - parsed: 36416 ETA: 0:37:09.540760
# calamancy dependecy parsing - parsed: 36544 ETA: 0:37:51.535631
# calamancy dependecy parsing - parsed: 36672 ETA: 0:37:49.410176
# calamancy dependecy parsing - parsed: 36800 ETA: 0:37:28.474905
# calamancy dependecy parsing - parsed: 36928 ETA: 0:39:09.954586
# calamancy dependecy parsing - parsed: 37056 ETA: 0:38:57.270045
# calamancy dependecy parsing - parsed: 37184 ETA: 0:38:40.422963
# calamancy dependecy parsing - parsed: 37312 ETA: 0:38:57.912995
# calamancy dependecy parsing - parsed: 37440 ETA: 0:39:24.161745
# calamancy dependecy parsing - parsed: 37568 ETA: 0:38:46.389387
# calamancy dependecy parsing - parsed: 37696 ETA: 0:38:53.285706
# calamancy dependecy parsing - parsed: 37824 ETA: 0:39:06.500393
# calamancy dependecy parsing - parsed: 37952 ETA: 0:39:22.252080
# calamancy dependecy parsing - parsed: 38080 ETA: 0:38:47.344939
# calamancy dependecy parsing - parsed: 38208 ETA: 0:38:08.631605
# calamancy dependecy parsing - parsed: 38336 ETA: 0:38:50.708557
# calamancy dependecy parsing - parsed: 38464 ETA: 0:38:51.714773
# calamancy dependecy parsing - parsed: 38592 ETA: 0:38:42.350769
# calamancy dependecy parsing - parsed: 38720 ETA: 0:39:30.507320
# calamancy dependecy parsing - parsed: 38848 ETA: 0:40:04.536182
# calamancy dependecy parsing - parsed: 38976 ETA: 0:40:02.583415
# calamancy dependecy parsing - parsed: 39104 ETA: 0:40:08.141562
# calamancy dependecy parsing - parsed: 39232 ETA: 0:39:53.617414
# calamancy dependecy parsing - parsed: 39360 ETA: 0:39:42.617129
# calamancy dependecy parsing - parsed: 39488 ETA: 0:39:24.120829
# calamancy dependecy parsing - parsed: 39616 ETA: 0:39:12.640214
# calamancy dependecy parsing - parsed: 39744 ETA: 0:39:09.545696
# calamancy dependecy parsing - parsed: 39872 ETA: 0:39:29.612193
# calamancy dependecy parsing - parsed: 40000 ETA: 0:38:28.606949
# calamancy dependecy parsing - parsed: 40128 ETA: 0:39:11.270870
# calamancy dependecy parsing - parsed: 40256 ETA: 0:38:49.103220
# calamancy dependecy parsing - parsed: 40384 ETA: 0:38:38.048129
# calamancy dependecy parsing - parsed: 40512 ETA: 0:38:28.044216
# calamancy dependecy parsing - parsed: 40640 ETA: 0:39:08.780506
# calamancy dependecy parsing - parsed: 40768 ETA: 0:38:16.394990
# calamancy dependecy parsing - parsed: 40896 ETA: 0:37:51.795529
# calamancy dependecy parsing - parsed: 41024 ETA: 0:38:07.286710
# calamancy dependecy parsing - parsed: 41152 ETA: 0:38:01.213294
# calamancy dependecy parsing - parsed: 41280 ETA: 0:38:18.025396
# calamancy dependecy parsing - parsed: 41408 ETA: 0:39:20.506639
# calamancy dependecy parsing - parsed: 41536 ETA: 0:40:11.204778
# calamancy dependecy parsing - parsed: 41664 ETA: 0:39:34.357795
# calamancy dependecy parsing - parsed: 41792 ETA: 0:40:13.046213
# calamancy dependecy parsing - parsed: 41920 ETA: 0:41:09.360886
# calamancy dependecy parsing - parsed: 42048 ETA: 0:41:26.512889
# calamancy dependecy parsing - parsed: 42176 ETA: 0:40:31.432031
# calamancy dependecy parsing - parsed: 42304 ETA: 0:41:26.812156
# calamancy dependecy parsing - parsed: 42432 ETA: 0:41:00.423488
# calamancy dependecy parsing - parsed: 42560 ETA: 0:39:55.305052
# calamancy dependecy parsing - parsed: 42688 ETA: 0:40:02.703225
# calamancy dependecy parsing - parsed: 42816 ETA: 0:40:52.209077
# calamancy dependecy parsing - parsed: 42944 ETA: 0:41:14.065044
# calamancy dependecy parsing - parsed: 43072 ETA: 0:42:24.377864
# calamancy dependecy parsing - parsed: 43200 ETA: 0:42:15.467100
# calamancy dependecy parsing - parsed: 43328 ETA: 0:40:54.100698
# calamancy dependecy parsing - parsed: 43456 ETA: 0:40:04.594369
# calamancy dependecy parsing - parsed: 43584 ETA: 0:38:30.117769
# calamancy dependecy parsing - parsed: 43712 ETA: 0:37:03.752508
# calamancy dependecy parsing - parsed: 43840 ETA: 0:37:30.581860
# calamancy dependecy parsing - parsed: 43968 ETA: 0:37:27.498044
# calamancy dependecy parsing - parsed: 44096 ETA: 0:37:54.040189
# calamancy dependecy parsing - parsed: 44224 ETA: 0:40:18.055740
# calamancy dependecy parsing - parsed: 44352 ETA: 0:41:23.727578
# calamancy dependecy parsing - parsed: 44480 ETA: 0:40:01.220109
# calamancy dependecy parsing - parsed: 44608 ETA: 0:39:48.982967
# calamancy dependecy parsing - parsed: 44736 ETA: 0:41:29.026114
# calamancy dependecy parsing - parsed: 44864 ETA: 0:39:42.847003
# calamancy dependecy parsing - parsed: 44992 ETA: 0:38:59.535098
# calamancy dependecy parsing - parsed: 45120 ETA: 0:39:52.721838
# calamancy dependecy parsing - parsed: 45248 ETA: 0:39:47.656891
# calamancy dependecy parsing - parsed: 45376 ETA: 0:37:50.858479
# calamancy dependecy parsing - parsed: 45504 ETA: 0:37:41.673974
# calamancy dependecy parsing - parsed: 45632 ETA: 0:37:40.606404
# calamancy dependecy parsing - parsed: 45760 ETA: 0:37:58.713000
# calamancy dependecy parsing - parsed: 45888 ETA: 0:38:01.238132
# calamancy dependecy parsing - parsed: 46016 ETA: 0:38:09.815046
# calamancy dependecy parsing - parsed: 46144 ETA: 0:39:24.355921
# calamancy dependecy parsing - parsed: 46272 ETA: 0:39:11.876080
# calamancy dependecy parsing - parsed: 46400 ETA: 0:39:46.351610
# calamancy dependecy parsing - parsed: 46528 ETA: 0:40:41.643368
# calamancy dependecy parsing - parsed: 46656 ETA: 0:41:44.477183
# calamancy dependecy parsing - parsed: 46784 ETA: 0:40:38.352629
# calamancy dependecy parsing - parsed: 46912 ETA: 0:40:43.727152
# calamancy dependecy parsing - parsed: 47040 ETA: 0:39:40.204937
# calamancy dependecy parsing - parsed: 47168 ETA: 0:38:55.733681
# calamancy dependecy parsing - parsed: 47296 ETA: 0:36:55.443910
# calamancy dependecy parsing - parsed: 47424 ETA: 0:38:52.470255
# calamancy dependecy parsing - parsed: 47552 ETA: 0:37:54.903484
# calamancy dependecy parsing - parsed: 47680 ETA: 0:38:01.807897
# calamancy dependecy parsing - parsed: 47808 ETA: 0:39:33.768411
# calamancy dependecy parsing - parsed: 47936 ETA: 0:41:00.833303
# calamancy dependecy parsing - parsed: 48064 ETA: 0:39:26.933643
# calamancy dependecy parsing - parsed: 48192 ETA: 0:40:08.035344
# calamancy dependecy parsing - parsed: 48320 ETA: 0:39:38.941125
# calamancy dependecy parsing - parsed: 48448 ETA: 0:37:58.920729
# calamancy dependecy parsing - parsed: 48576 ETA: 0:37:24.958991
# calamancy dependecy parsing - parsed: 48704 ETA: 0:37:12.194641
# calamancy dependecy parsing - parsed: 48832 ETA: 0:36:39.081559
# calamancy dependecy parsing - parsed: 48960 ETA: 0:37:43.181309
# calamancy dependecy parsing - parsed: 49088 ETA: 0:37:53.092599
# calamancy dependecy parsing - parsed: 49216 ETA: 0:37:40.521446
# calamancy dependecy parsing - parsed: 49344 ETA: 0:37:05.332871
# calamancy dependecy parsing - parsed: 49472 ETA: 0:36:54.948401
# calamancy dependecy parsing - parsed: 49600 ETA: 0:36:04.364404
# calamancy dependecy parsing - parsed: 49728 ETA: 0:35:24.037230
# calamancy dependecy parsing - parsed: 49856 ETA: 0:35:07.668933
# calamancy dependecy parsing - parsed: 49984 ETA: 0:35:35.725688
# calamancy dependecy parsing - parsed: 50112 ETA: 0:36:39.016656
# calamancy dependecy parsing - parsed: 50240 ETA: 0:36:27.534387
# calamancy dependecy parsing - parsed: 50368 ETA: 0:37:46.339086
# calamancy dependecy parsing - parsed: 50496 ETA: 0:38:16.335209
# calamancy dependecy parsing - parsed: 50624 ETA: 0:38:34.406024
# calamancy dependecy parsing - parsed: 50752 ETA: 0:37:33.352717
# calamancy dependecy parsing - parsed: 50880 ETA: 0:38:53.960990
# calamancy dependecy parsing - parsed: 51008 ETA: 0:37:47.868604
# calamancy dependecy parsing - parsed: 51136 ETA: 0:37:02.430145
# calamancy dependecy parsing - parsed: 51264 ETA: 0:37:10.964159
# calamancy dependecy parsing - parsed: 51392 ETA: 0:37:10.014530
# calamancy dependecy parsing - parsed: 51520 ETA: 0:35:10.524230
# calamancy dependecy parsing - parsed: 51648 ETA: 0:35:38.608864
# calamancy dependecy parsing - parsed: 51776 ETA: 0:35:50.566305
# calamancy dependecy parsing - parsed: 51904 ETA: 0:35:10.342033
# calamancy dependecy parsing - parsed: 52032 ETA: 0:35:38.889742
# calamancy dependecy parsing - parsed: 52160 ETA: 0:36:35.886758
# calamancy dependecy parsing - parsed: 52288 ETA: 0:36:17.345512
# calamancy dependecy parsing - parsed: 52416 ETA: 0:36:19.778970
# calamancy dependecy parsing - parsed: 52544 ETA: 0:37:13.050788
# calamancy dependecy parsing - parsed: 52672 ETA: 0:36:36.087320
# calamancy dependecy parsing - parsed: 52800 ETA: 0:35:44.433871
# calamancy dependecy parsing - parsed: 52928 ETA: 0:36:27.979837
# calamancy dependecy parsing - parsed: 53056 ETA: 0:36:44.009768
# calamancy dependecy parsing - parsed: 53184 ETA: 0:36:01.842800
# calamancy dependecy parsing - parsed: 53312 ETA: 0:36:31.538306
# calamancy dependecy parsing - parsed: 53440 ETA: 0:37:58.552144
# calamancy dependecy parsing - parsed: 53568 ETA: 0:37:16.410510
# calamancy dependecy parsing - parsed: 53696 ETA: 0:36:31.968434
# calamancy dependecy parsing - parsed: 53824 ETA: 0:35:44.548257
# calamancy dependecy parsing - parsed: 53952 ETA: 0:34:28.870670
# calamancy dependecy parsing - parsed: 54080 ETA: 0:32:22.486137
# calamancy dependecy parsing - parsed: 54208 ETA: 0:31:29.354388
# calamancy dependecy parsing - parsed: 54336 ETA: 0:31:33.975109
# calamancy dependecy parsing - parsed: 54464 ETA: 0:31:37.191044
# calamancy dependecy parsing - parsed: 54592 ETA: 0:32:58.988970
# calamancy dependecy parsing - parsed: 54720 ETA: 0:34:18.569287
# calamancy dependecy parsing - parsed: 54848 ETA: 0:35:55.058905
# calamancy dependecy parsing - parsed: 54976 ETA: 0:36:04.076909
# calamancy dependecy parsing - parsed: 55104 ETA: 0:35:37.928826
# calamancy dependecy parsing - parsed: 55232 ETA: 0:35:25.746757
# calamancy dependecy parsing - parsed: 55360 ETA: 0:35:10.466333
# calamancy dependecy parsing - parsed: 55488 ETA: 0:33:28.842515
# calamancy dependecy parsing - parsed: 55616 ETA: 0:34:26.816684
# calamancy dependecy parsing - parsed: 55744 ETA: 0:34:55.508561
# calamancy dependecy parsing - parsed: 55872 ETA: 0:34:16.150815
# calamancy dependecy parsing - parsed: 56000 ETA: 0:34:01.563696
# calamancy dependecy parsing - parsed: 56128 ETA: 0:34:27.538623
# calamancy dependecy parsing - parsed: 56256 ETA: 0:33:43.492325
# calamancy dependecy parsing - parsed: 56384 ETA: 0:33:31.650329
# calamancy dependecy parsing - parsed: 56512 ETA: 0:33:37.333258
# calamancy dependecy parsing - parsed: 56640 ETA: 0:33:03.461160
# calamancy dependecy parsing - parsed: 56768 ETA: 0:33:56.123455
# calamancy dependecy parsing - parsed: 56896 ETA: 0:33:16.045216
# calamancy dependecy parsing - parsed: 57024 ETA: 0:32:53.223178
# calamancy dependecy parsing - parsed: 57152 ETA: 0:33:53.586881
# calamancy dependecy parsing - parsed: 57280 ETA: 0:34:00.081613
# calamancy dependecy parsing - parsed: 57408 ETA: 0:32:41.654019
# calamancy dependecy parsing - parsed: 57536 ETA: 0:33:08.201408
# calamancy dependecy parsing - parsed: 57664 ETA: 0:34:26.073972
# calamancy dependecy parsing - parsed: 57792 ETA: 0:34:19.302587
# calamancy dependecy parsing - parsed: 57920 ETA: 0:35:47.969557
# calamancy dependecy parsing - parsed: 58048 ETA: 0:36:41.336738
# calamancy dependecy parsing - parsed: 58176 ETA: 0:36:51.552836
# calamancy dependecy parsing - parsed: 58304 ETA: 0:36:08.390434
# calamancy dependecy parsing - parsed: 58432 ETA: 0:37:30.590702
# calamancy dependecy parsing - parsed: 58560 ETA: 0:36:19.148596
# calamancy dependecy parsing - parsed: 58688 ETA: 0:35:59.513435
# calamancy dependecy parsing - parsed: 58816 ETA: 0:35:43.078377
# calamancy dependecy parsing - parsed: 58944 ETA: 0:35:42.934389
# calamancy dependecy parsing - parsed: 59072 ETA: 0:32:48.201808
# calamancy dependecy parsing - parsed: 59200 ETA: 0:32:30.006344
# calamancy dependecy parsing - parsed: 59328 ETA: 0:32:25.088398
# calamancy dependecy parsing - parsed: 59456 ETA: 0:32:03.495768
# calamancy dependecy parsing - parsed: 59584 ETA: 0:31:18.677749
# calamancy dependecy parsing - parsed: 59712 ETA: 0:31:22.294001
# calamancy dependecy parsing - parsed: 59840 ETA: 0:31:21.644472
# calamancy dependecy parsing - parsed: 59968 ETA: 0:31:47.338605
# calamancy dependecy parsing - parsed: 60096 ETA: 0:31:58.053746
# calamancy dependecy parsing - parsed: 60224 ETA: 0:31:45.841421
# calamancy dependecy parsing - parsed: 60352 ETA: 0:31:46.371319
# calamancy dependecy parsing - parsed: 60480 ETA: 0:31:11.484405
# calamancy dependecy parsing - parsed: 60608 ETA: 0:31:15.011737
# calamancy dependecy parsing - parsed: 60736 ETA: 0:31:12.364655
# calamancy dependecy parsing - parsed: 60864 ETA: 0:31:14.110393
# calamancy dependecy parsing - parsed: 60992 ETA: 0:31:25.529755
# calamancy dependecy parsing - parsed: 61120 ETA: 0:31:32.671143
# calamancy dependecy parsing - parsed: 61248 ETA: 0:30:55.955711
# calamancy dependecy parsing - parsed: 61376 ETA: 0:31:01.769588
# calamancy dependecy parsing - parsed: 61504 ETA: 0:31:29.961158
# calamancy dependecy parsing - parsed: 61632 ETA: 0:31:30.823114
# calamancy dependecy parsing - parsed: 61760 ETA: 0:33:01.997572
# calamancy dependecy parsing - parsed: 61888 ETA: 0:32:28.441807
# calamancy dependecy parsing - parsed: 62016 ETA: 0:32:26.892943
# calamancy dependecy parsing - parsed: 62144 ETA: 0:31:35.846526
# calamancy dependecy parsing - parsed: 62272 ETA: 0:32:07.487982
# calamancy dependecy parsing - parsed: 62400 ETA: 0:30:38.468225
# calamancy dependecy parsing - parsed: 62528 ETA: 0:30:50.299997
# calamancy dependecy parsing - parsed: 62656 ETA: 0:30:56.615129
# calamancy dependecy parsing - parsed: 62784 ETA: 0:31:35.140554
# calamancy dependecy parsing - parsed: 62912 ETA: 0:30:40.966154
# calamancy dependecy parsing - parsed: 63040 ETA: 0:32:03.270747
# calamancy dependecy parsing - parsed: 63168 ETA: 0:31:53.885619
# calamancy dependecy parsing - parsed: 63296 ETA: 0:32:20.401503
# calamancy dependecy parsing - parsed: 63424 ETA: 0:34:10.439212
# calamancy dependecy parsing - parsed: 63552 ETA: 0:35:11.790754
# calamancy dependecy parsing - parsed: 63680 ETA: 0:33:49.847615
# calamancy dependecy parsing - parsed: 63808 ETA: 0:33:23.402527
# calamancy dependecy parsing - parsed: 63936 ETA: 0:32:13.181410
# calamancy dependecy parsing - parsed: 64064 ETA: 0:30:09.642465
# calamancy dependecy parsing - parsed: 64192 ETA: 0:29:15.825605
# calamancy dependecy parsing - parsed: 64320 ETA: 0:29:04.652820
# calamancy dependecy parsing - parsed: 64448 ETA: 0:29:31.160976
# calamancy dependecy parsing - parsed: 64576 ETA: 0:28:58.801400
# calamancy dependecy parsing - parsed: 64704 ETA: 0:29:34.923716
# calamancy dependecy parsing - parsed: 64832 ETA: 0:30:09.666948
# calamancy dependecy parsing - parsed: 64960 ETA: 0:30:45.675710
# calamancy dependecy parsing - parsed: 65088 ETA: 0:30:36.422449
# calamancy dependecy parsing - parsed: 65216 ETA: 0:31:57.776801
# calamancy dependecy parsing - parsed: 65344 ETA: 0:31:23.913516
# calamancy dependecy parsing - parsed: 65472 ETA: 0:31:07.292310
# calamancy dependecy parsing - parsed: 65600 ETA: 0:31:14.874043
# calamancy dependecy parsing - parsed: 65728 ETA: 0:31:03.174587
# calamancy dependecy parsing - parsed: 65856 ETA: 0:30:03.418000
# calamancy dependecy parsing - parsed: 65984 ETA: 0:29:48.355542
# calamancy dependecy parsing - parsed: 66112 ETA: 0:29:09.835725
# calamancy dependecy parsing - parsed: 66240 ETA: 0:28:22.409790
# calamancy dependecy parsing - parsed: 66368 ETA: 0:28:01.782486
# calamancy dependecy parsing - parsed: 66496 ETA: 0:27:57.939958
# calamancy dependecy parsing - parsed: 66624 ETA: 0:28:06.257515
# calamancy dependecy parsing - parsed: 66752 ETA: 0:29:17.163600
# calamancy dependecy parsing - parsed: 66880 ETA: 0:29:43.507430
# calamancy dependecy parsing - parsed: 67008 ETA: 0:31:04.896861
# calamancy dependecy parsing - parsed: 67136 ETA: 0:31:11.528258
# calamancy dependecy parsing - parsed: 67264 ETA: 0:32:19.221681
# calamancy dependecy parsing - parsed: 67392 ETA: 0:31:42.195351
# calamancy dependecy parsing - parsed: 67520 ETA: 0:31:52.488799
# calamancy dependecy parsing - parsed: 67648 ETA: 0:30:38.939798
# calamancy dependecy parsing - parsed: 67776 ETA: 0:31:19.214678
# calamancy dependecy parsing - parsed: 67904 ETA: 0:30:45.821775
# calamancy dependecy parsing - parsed: 68032 ETA: 0:32:29.904568
# calamancy dependecy parsing - parsed: 68160 ETA: 0:37:40.932641
# calamancy dependecy parsing - parsed: 68288 ETA: 0:40:37.263473
# calamancy dependecy parsing - parsed: 68416 ETA: 0:41:02.317959
# calamancy dependecy parsing - parsed: 68544 ETA: 0:40:05.276953
# calamancy dependecy parsing - parsed: 68672 ETA: 0:39:41.840447
# calamancy dependecy parsing - parsed: 68800 ETA: 0:33:44.861029
# calamancy dependecy parsing - parsed: 68928 ETA: 0:30:56.570224
# calamancy dependecy parsing - parsed: 69056 ETA: 0:29:38.930395
# calamancy dependecy parsing - parsed: 69184 ETA: 0:30:00.772147
# calamancy dependecy parsing - parsed: 69312 ETA: 0:27:56.914823
# calamancy dependecy parsing - parsed: 69440 ETA: 0:30:05.017657
# calamancy dependecy parsing - parsed: 69568 ETA: 0:29:52.673057
# calamancy dependecy parsing - parsed: 69696 ETA: 0:29:32.868654
# calamancy dependecy parsing - parsed: 69824 ETA: 0:29:55.151753
# calamancy dependecy parsing - parsed: 69952 ETA: 0:31:03.192010
# calamancy dependecy parsing - parsed: 70080 ETA: 0:28:54.767861
# calamancy dependecy parsing - parsed: 70208 ETA: 0:29:09.500644
# calamancy dependecy parsing - parsed: 70336 ETA: 0:29:05.603520
# calamancy dependecy parsing - parsed: 70464 ETA: 0:29:38.367982
# calamancy dependecy parsing - parsed: 70592 ETA: 0:29:14.967300
# calamancy dependecy parsing - parsed: 70720 ETA: 0:29:12.797648
# calamancy dependecy parsing - parsed: 70848 ETA: 0:30:05.558485
# calamancy dependecy parsing - parsed: 70976 ETA: 0:30:36.571531
# calamancy dependecy parsing - parsed: 71104 ETA: 0:29:19.781860
# calamancy dependecy parsing - parsed: 71232 ETA: 0:28:54.869460
# calamancy dependecy parsing - parsed: 71360 ETA: 0:28:58.316892
# calamancy dependecy parsing - parsed: 71488 ETA: 0:27:33.025318
# calamancy dependecy parsing - parsed: 71616 ETA: 0:27:20.685655
# calamancy dependecy parsing - parsed: 71744 ETA: 0:27:01.141018
# calamancy dependecy parsing - parsed: 71872 ETA: 0:26:10.611753
# calamancy dependecy parsing - parsed: 72000 ETA: 0:26:35.531847
# calamancy dependecy parsing - parsed: 72128 ETA: 0:27:15.368459
# calamancy dependecy parsing - parsed: 72256 ETA: 0:27:08.062247
# calamancy dependecy parsing - parsed: 72384 ETA: 0:27:14.477039
# calamancy dependecy parsing - parsed: 72512 ETA: 0:28:10.306186
# calamancy dependecy parsing - parsed: 72640 ETA: 0:27:49.914182
# calamancy dependecy parsing - parsed: 72768 ETA: 0:27:26.742703
# calamancy dependecy parsing - parsed: 72896 ETA: 0:28:20.181941
# calamancy dependecy parsing - parsed: 73024 ETA: 0:28:28.122835
# calamancy dependecy parsing - parsed: 73152 ETA: 0:31:26.288378
# calamancy dependecy parsing - parsed: 73280 ETA: 0:34:25.052307
# calamancy dependecy parsing - parsed: 73408 ETA: 0:37:16.103137
# calamancy dependecy parsing - parsed: 73536 ETA: 0:36:28.719193
# calamancy dependecy parsing - parsed: 73664 ETA: 0:36:40.565737
# calamancy dependecy parsing - parsed: 73792 ETA: 0:32:51.985872
# calamancy dependecy parsing - parsed: 73920 ETA: 0:29:51.718726
# calamancy dependecy parsing - parsed: 74048 ETA: 0:27:04.285276
# calamancy dependecy parsing - parsed: 74176 ETA: 0:27:29.353057
# calamancy dependecy parsing - parsed: 74304 ETA: 0:27:51.784925
# calamancy dependecy parsing - parsed: 74432 ETA: 0:28:08.707282
# calamancy dependecy parsing - parsed: 74560 ETA: 0:27:55.511032
# calamancy dependecy parsing - parsed: 74688 ETA: 0:27:45.952499
# calamancy dependecy parsing - parsed: 74816 ETA: 0:27:08.184456
# calamancy dependecy parsing - parsed: 74944 ETA: 0:27:32.066728
# calamancy dependecy parsing - parsed: 75072 ETA: 0:27:33.632855
# calamancy dependecy parsing - parsed: 75200 ETA: 0:28:31.417798
# calamancy dependecy parsing - parsed: 75328 ETA: 0:29:25.388438
# calamancy dependecy parsing - parsed: 75456 ETA: 0:28:57.694390
# calamancy dependecy parsing - parsed: 75584 ETA: 0:28:12.835512
# calamancy dependecy parsing - parsed: 75712 ETA: 0:28:07.174600
# calamancy dependecy parsing - parsed: 75840 ETA: 0:26:43.677352
# calamancy dependecy parsing - parsed: 75968 ETA: 0:25:52.815879
# calamancy dependecy parsing - parsed: 76096 ETA: 0:25:50.730890
# calamancy dependecy parsing - parsed: 76224 ETA: 0:24:59.327969
# calamancy dependecy parsing - parsed: 76352 ETA: 0:25:50.023529
# calamancy dependecy parsing - parsed: 76480 ETA: 0:25:40.174571
# calamancy dependecy parsing - parsed: 76608 ETA: 0:25:09.029875
# calamancy dependecy parsing - parsed: 76736 ETA: 0:25:19.343181
# calamancy dependecy parsing - parsed: 76864 ETA: 0:26:15.041595
# calamancy dependecy parsing - parsed: 76992 ETA: 0:24:41.806028
# calamancy dependecy parsing - parsed: 77120 ETA: 0:24:27.270443
# calamancy dependecy parsing - parsed: 77248 ETA: 0:25:01.490271
# calamancy dependecy parsing - parsed: 77376 ETA: 0:24:22.767960
# calamancy dependecy parsing - parsed: 77504 ETA: 0:23:13.071421
# calamancy dependecy parsing - parsed: 77632 ETA: 0:23:08.425268
# calamancy dependecy parsing - parsed: 77760 ETA: 0:23:13.984272
# calamancy dependecy parsing - parsed: 77888 ETA: 0:22:09.693480
# calamancy dependecy parsing - parsed: 78016 ETA: 0:22:26.246225
# calamancy dependecy parsing - parsed: 78144 ETA: 0:22:34.506442
# calamancy dependecy parsing - parsed: 78272 ETA: 0:22:34.797055
# calamancy dependecy parsing - parsed: 78400 ETA: 0:22:42.762331
# calamancy dependecy parsing - parsed: 78528 ETA: 0:23:18.415090
# calamancy dependecy parsing - parsed: 78656 ETA: 0:23:24.377056
# calamancy dependecy parsing - parsed: 78784 ETA: 0:23:51.288659
# calamancy dependecy parsing - parsed: 78912 ETA: 0:23:45.595263
# calamancy dependecy parsing - parsed: 79040 ETA: 0:26:22.299865
# calamancy dependecy parsing - parsed: 79168 ETA: 0:29:43.672536
# calamancy dependecy parsing - parsed: 79296 ETA: 0:30:07.443449
# calamancy dependecy parsing - parsed: 79424 ETA: 0:29:21.819479
# calamancy dependecy parsing - parsed: 79552 ETA: 0:29:28.129682
# calamancy dependecy parsing - parsed: 79680 ETA: 0:26:11.195649
# calamancy dependecy parsing - parsed: 79808 ETA: 0:23:01.778409
# calamancy dependecy parsing - parsed: 79936 ETA: 0:23:19.580312
# calamancy dependecy parsing - parsed: 80064 ETA: 0:23:25.122925
# calamancy dependecy parsing - parsed: 80192 ETA: 0:23:55.439639
# calamancy dependecy parsing - parsed: 80320 ETA: 0:24:30.712343
# calamancy dependecy parsing - parsed: 80448 ETA: 0:23:41.750039
# calamancy dependecy parsing - parsed: 80576 ETA: 0:23:30.569886
# calamancy dependecy parsing - parsed: 80704 ETA: 0:24:27.297629
# calamancy dependecy parsing - parsed: 80832 ETA: 0:24:47.838970
# calamancy dependecy parsing - parsed: 80960 ETA: 0:25:36.136250
# calamancy dependecy parsing - parsed: 81088 ETA: 0:25:23.539763
# calamancy dependecy parsing - parsed: 81216 ETA: 0:24:35.281010
# calamancy dependecy parsing - parsed: 81344 ETA: 0:23:23.984313
# calamancy dependecy parsing - parsed: 81472 ETA: 0:22:20.417162
# calamancy dependecy parsing - parsed: 81600 ETA: 0:21:32.580430
# calamancy dependecy parsing - parsed: 81728 ETA: 0:21:36.251587
# calamancy dependecy parsing - parsed: 81856 ETA: 0:21:25.352043
# calamancy dependecy parsing - parsed: 81984 ETA: 0:21:22.037919
# calamancy dependecy parsing - parsed: 82112 ETA: 0:21:01.794322
# calamancy dependecy parsing - parsed: 82240 ETA: 0:20:12.489550
# calamancy dependecy parsing - parsed: 82368 ETA: 0:19:41.316934
# calamancy dependecy parsing - parsed: 82496 ETA: 0:19:42.081375
# calamancy dependecy parsing - parsed: 82624 ETA: 0:19:36.556400
# calamancy dependecy parsing - parsed: 82752 ETA: 0:19:42.524250
# calamancy dependecy parsing - parsed: 82880 ETA: 0:19:45.517198
# calamancy dependecy parsing - parsed: 83008 ETA: 0:23:28.718772
# calamancy dependecy parsing - parsed: 83136 ETA: 0:24:13.674362
# calamancy dependecy parsing - parsed: 83264 ETA: 0:24:29.789440
# calamancy dependecy parsing - parsed: 83392 ETA: 0:24:55.936519
# calamancy dependecy parsing - parsed: 83520 ETA: 0:24:50.200206
# calamancy dependecy parsing - parsed: 83648 ETA: 0:21:24.498022
# calamancy dependecy parsing - parsed: 83776 ETA: 0:20:35.583995
# calamancy dependecy parsing - parsed: 83904 ETA: 0:19:53.513536
# calamancy dependecy parsing - parsed: 84032 ETA: 0:22:42.652737
# calamancy dependecy parsing - parsed: 84160 ETA: 0:25:53.737469
# calamancy dependecy parsing - parsed: 84288 ETA: 0:29:17.913489
# calamancy dependecy parsing - parsed: 84416 ETA: 0:30:14.578336
# calamancy dependecy parsing - parsed: 84544 ETA: 0:30:33.421352
# calamancy dependecy parsing - parsed: 84672 ETA: 0:28:00.361202
# calamancy dependecy parsing - parsed: 84800 ETA: 0:25:47.918506
# calamancy dependecy parsing - parsed: 84928 ETA: 0:22:39.261898
# calamancy dependecy parsing - parsed: 85056 ETA: 0:22:21.891605
# calamancy dependecy parsing - parsed: 85184 ETA: 0:23:04.847589
# calamancy dependecy parsing - parsed: 85312 ETA: 0:23:25.173118
# calamancy dependecy parsing - parsed: 85440 ETA: 0:23:27.318340
# calamancy dependecy parsing - parsed: 85568 ETA: 0:23:31.507468
# calamancy dependecy parsing - parsed: 85696 ETA: 0:23:55.379026
# calamancy dependecy parsing - parsed: 85824 ETA: 0:23:31.268552
# calamancy dependecy parsing - parsed: 85952 ETA: 0:22:41.552066
# calamancy dependecy parsing - parsed: 86080 ETA: 0:22:17.063158
# calamancy dependecy parsing - parsed: 86208 ETA: 0:22:21.626608
# calamancy dependecy parsing - parsed: 86336 ETA: 0:21:49.277843
# calamancy dependecy parsing - parsed: 86464 ETA: 0:22:02.253432
# calamancy dependecy parsing - parsed: 86592 ETA: 0:22:47.214557
# calamancy dependecy parsing - parsed: 86720 ETA: 0:22:23.187360
# calamancy dependecy parsing - parsed: 86848 ETA: 0:23:05.369035
# calamancy dependecy parsing - parsed: 86976 ETA: 0:23:25.183830
# calamancy dependecy parsing - parsed: 87104 ETA: 0:24:14.038978
# calamancy dependecy parsing - parsed: 87232 ETA: 0:23:59.308313
# calamancy dependecy parsing - parsed: 87360 ETA: 0:24:04.743918
# calamancy dependecy parsing - parsed: 87488 ETA: 0:22:54.664338
# calamancy dependecy parsing - parsed: 87616 ETA: 0:22:02.027111
# calamancy dependecy parsing - parsed: 87744 ETA: 0:20:37.201062
# calamancy dependecy parsing - parsed: 87872 ETA: 0:20:01.234789
# calamancy dependecy parsing - parsed: 88000 ETA: 0:21:02.897667
# calamancy dependecy parsing - parsed: 88128 ETA: 0:21:51.144988
# calamancy dependecy parsing - parsed: 88256 ETA: 0:21:33.112433
# calamancy dependecy parsing - parsed: 88384 ETA: 0:21:24.536455
# calamancy dependecy parsing - parsed: 88512 ETA: 0:20:56.721622
# calamancy dependecy parsing - parsed: 88640 ETA: 0:19:54.129947
# calamancy dependecy parsing - parsed: 88768 ETA: 0:19:40.469042
# calamancy dependecy parsing - parsed: 88896 ETA: 0:19:43.897722
# calamancy dependecy parsing - parsed: 89024 ETA: 0:22:44.067377
# calamancy dependecy parsing - parsed: 89152 ETA: 0:25:53.672820
# calamancy dependecy parsing - parsed: 89280 ETA: 0:27:44.387859
# calamancy dependecy parsing - parsed: 89408 ETA: 0:27:21.572842
# calamancy dependecy parsing - parsed: 89536 ETA: 0:27:17.067646
# calamancy dependecy parsing - parsed: 89664 ETA: 0:24:19.211145
# calamancy dependecy parsing - parsed: 89792 ETA: 0:21:32.143820
# calamancy dependecy parsing - parsed: 89920 ETA: 0:20:28.134819
# calamancy dependecy parsing - parsed: 90048 ETA: 0:20:09.082954
# calamancy dependecy parsing - parsed: 90176 ETA: 0:20:08.404904
# calamancy dependecy parsing - parsed: 90304 ETA: 0:21:59.953975
# calamancy dependecy parsing - parsed: 90432 ETA: 0:24:06.177904
# calamancy dependecy parsing - parsed: 90560 ETA: 0:24:38.844284
# calamancy dependecy parsing - parsed: 90688 ETA: 0:25:42.545689
# calamancy dependecy parsing - parsed: 90816 ETA: 0:26:32.309607
# calamancy dependecy parsing - parsed: 90944 ETA: 0:26:09.338489
# calamancy dependecy parsing - parsed: 91072 ETA: 0:24:55.354075
# calamancy dependecy parsing - parsed: 91200 ETA: 0:24:29.066306
# calamancy dependecy parsing - parsed: 91328 ETA: 0:23:54.958479
# calamancy dependecy parsing - parsed: 91456 ETA: 0:22:48.384706
# calamancy dependecy parsing - parsed: 91584 ETA: 0:21:24.015630
# calamancy dependecy parsing - parsed: 91712 ETA: 0:22:49.367486
# calamancy dependecy parsing - parsed: 91840 ETA: 0:23:50.095509
# calamancy dependecy parsing - parsed: 91968 ETA: 0:25:18.693263
# calamancy dependecy parsing - parsed: 92096 ETA: 0:28:58.602494
# calamancy dependecy parsing - parsed: 92224 ETA: 0:31:28.990868
# calamancy dependecy parsing - parsed: 92352 ETA: 0:31:28.775314
# calamancy dependecy parsing - parsed: 92480 ETA: 0:31:54.433466
# calamancy dependecy parsing - parsed: 92608 ETA: 0:33:12.496102
# calamancy dependecy parsing - parsed: 92736 ETA: 0:32:49.986048
# calamancy dependecy parsing - parsed: 92864 ETA: 0:32:58.715769
# calamancy dependecy parsing - parsed: 92992 ETA: 0:32:04.590076
# calamancy dependecy parsing - parsed: 93120 ETA: 0:31:30.392512
# calamancy dependecy parsing - parsed: 93248 ETA: 0:30:06.077130
# calamancy dependecy parsing - parsed: 93376 ETA: 0:29:06.048983
# calamancy dependecy parsing - parsed: 93504 ETA: 0:28:25.794428
# calamancy dependecy parsing - parsed: 93632 ETA: 0:28:44.464669
# calamancy dependecy parsing - parsed: 93760 ETA: 0:28:45.842825
# calamancy dependecy parsing - parsed: 93888 ETA: 0:29:49.437281
# calamancy dependecy parsing - parsed: 94016 ETA: 0:31:37.863964
# calamancy dependecy parsing - parsed: 94144 ETA: 0:31:27.491724
# calamancy dependecy parsing - parsed: 94272 ETA: 0:31:30.436966
# calamancy dependecy parsing - parsed: 94400 ETA: 0:31:31.962958
# calamancy dependecy parsing - parsed: 94528 ETA: 0:29:55.643510
# calamancy dependecy parsing - parsed: 94656 ETA: 0:27:24.045201
# calamancy dependecy parsing - parsed: 94784 ETA: 0:27:31.150371
# calamancy dependecy parsing - parsed: 94912 ETA: 0:27:31.479730
# calamancy dependecy parsing - parsed: 95040 ETA: 0:27:29.695776
# calamancy dependecy parsing - parsed: 95168 ETA: 0:27:23.506151
# calamancy dependecy parsing - parsed: 95296 ETA: 0:27:39.496447
# calamancy dependecy parsing - parsed: 95424 ETA: 0:27:40.311206
# calamancy dependecy parsing - parsed: 95552 ETA: 0:27:00.792847
# calamancy dependecy parsing - parsed: 95680 ETA: 0:26:55.704354
# calamancy dependecy parsing - parsed: 95808 ETA: 0:27:21.779771
# calamancy dependecy parsing - parsed: 95936 ETA: 0:27:27.356534
# calamancy dependecy parsing - parsed: 96064 ETA: 0:27:05.893956
# ...
# calamancy dependecy parsing - parsed: 112320 ETA: 0:17:49.926195
# calamancy dependecy parsing - parsed: 112448 ETA: 0:17:47.229876
# calamancy dependecy parsing - parsed: 112576 ETA: 0:17:34.022905
# calamancy dependecy parsing - parsed: 112704 ETA: 0:17:28.932118
# calamancy dependecy parsing - parsed: 112832 ETA: 0:17:49.962050
# calamancy dependecy parsing - parsed: 112960 ETA: 0:17:35.744525
# calamancy dependecy parsing - parsed: 113088 ETA: 0:17:05.392300
# calamancy dependecy parsing - parsed: 113216 ETA: 0:17:20.762503
# calamancy dependecy parsing - parsed: 113344 ETA: 0:17:18.550758
# calamancy dependecy parsing - parsed: 113472 ETA: 0:16:59.922374
# calamancy dependecy parsing - parsed: 113600 ETA: 0:16:32.402630
# calamancy dependecy parsing - parsed: 113728 ETA: 0:16:59.124792
# calamancy dependecy parsing - parsed: 113856 ETA: 0:16:47.150008
# calamancy dependecy parsing - parsed: 113984 ETA: 0:16:49.450686
# calamancy dependecy parsing - parsed: 114112 ETA: 0:16:25.827196
# calamancy dependecy parsing - parsed: 114240 ETA: 0:16:23.654650
# calamancy dependecy parsing - parsed: 114368 ETA: 0:16:03.529319
# calamancy dependecy parsing - parsed: 114496 ETA: 0:16:09.141674
# calamancy dependecy parsing - parsed: 114624 ETA: 0:15:52.382557
# calamancy dependecy parsing - parsed: 114752 ETA: 0:15:52.768747
# calamancy dependecy parsing - parsed: 114880 ETA: 0:15:46.914357
# calamancy dependecy parsing - parsed: 115008 ETA: 0:15:20.240132
# calamancy dependecy parsing - parsed: 115136 ETA: 0:15:13.950984
# calamancy dependecy parsing - parsed: 115264 ETA: 0:15:15.170220
# calamancy dependecy parsing - parsed: 115392 ETA: 0:15:09.586663
# calamancy dependecy parsing - parsed: 115520 ETA: 0:15:45.749576
# calamancy dependecy parsing - parsed: 115648 ETA: 0:16:02.362000
# calamancy dependecy parsing - parsed: 115776 ETA: 0:15:53.134878
# calamancy dependecy parsing - parsed: 115904 ETA: 0:15:47.142658
# calamancy dependecy parsing - parsed: 116032 ETA: 0:15:45.276966
# calamancy dependecy parsing - parsed: 116160 ETA: 0:15:21.077688
# calamancy dependecy parsing - parsed: 116288 ETA: 0:15:14.554882
# calamancy dependecy parsing - parsed: 116416 ETA: 0:15:10.474233
# calamancy dependecy parsing - parsed: 116544 ETA: 0:15:00.867350
# calamancy dependecy parsing - parsed: 116672 ETA: 0:14:30.648624
# calamancy dependecy parsing - parsed: 116800 ETA: 0:14:06.506967
# calamancy dependecy parsing - parsed: 116928 ETA: 0:14:29.762393
# calamancy dependecy parsing - parsed: 117056 ETA: 0:14:14.528527
# calamancy dependecy parsing - parsed: 117184 ETA: 0:13:54.463637
# calamancy dependecy parsing - parsed: 117312 ETA: 0:14:30.457483
# calamancy dependecy parsing - parsed: 117440 ETA: 0:15:07.896603
# calamancy dependecy parsing - parsed: 117568 ETA: 0:14:30.165382
# calamancy dependecy parsing - parsed: 117696 ETA: 0:14:56.466121
# calamancy dependecy parsing - parsed: 117824 ETA: 0:15:18.455358
# calamancy dependecy parsing - parsed: 117952 ETA: 0:14:48.080487
# calamancy dependecy parsing - parsed: 118080 ETA: 0:14:48.920816
# calamancy dependecy parsing - parsed: 118208 ETA: 0:15:05.912643
# calamancy dependecy parsing - parsed: 118336 ETA: 0:15:21.464893
# calamancy dependecy parsing - parsed: 118464 ETA: 0:15:44.312701
# calamancy dependecy parsing - parsed: 118592 ETA: 0:15:58.578180
# calamancy dependecy parsing - parsed: 118720 ETA: 0:15:00.032383
# calamancy dependecy parsing - parsed: 118848 ETA: 0:14:33.350091
# calamancy dependecy parsing - parsed: 118976 ETA: 0:13:40.919017
# calamancy dependecy parsing - parsed: 119104 ETA: 0:13:31.534597
# calamancy dependecy parsing - parsed: 119232 ETA: 0:13:19.587879
# calamancy dependecy parsing - parsed: 119360 ETA: 0:13:47.673834
# calamancy dependecy parsing - parsed: 119488 ETA: 0:14:09.379603
# calamancy dependecy parsing - parsed: 119616 ETA: 0:14:20.662682
# calamancy dependecy parsing - parsed: 119744 ETA: 0:13:37.821480
# calamancy dependecy parsing - parsed: 119872 ETA: 0:13:09.517529
# calamancy dependecy parsing - parsed: 120000 ETA: 0:12:48.676406
# calamancy dependecy parsing - parsed: 120128 ETA: 0:12:20.598183
# calamancy dependecy parsing - parsed: 120256 ETA: 0:11:54.218131
# calamancy dependecy parsing - parsed: 120384 ETA: 0:11:54.197310
# calamancy dependecy parsing - parsed: 120512 ETA: 0:11:59.316217
# calamancy dependecy parsing - parsed: 120640 ETA: 0:12:04.428832
# calamancy dependecy parsing - parsed: 120768 ETA: 0:11:57.860576
# calamancy dependecy parsing - parsed: 120896 ETA: 0:12:06.888856
# calamancy dependecy parsing - parsed: 121024 ETA: 0:11:47.332751
# calamancy dependecy parsing - parsed: 121152 ETA: 0:11:45.203361
# calamancy dependecy parsing - parsed: 121280 ETA: 0:11:26.166160
# calamancy dependecy parsing - parsed: 121408 ETA: 0:11:29.658933
# calamancy dependecy parsing - parsed: 121536 ETA: 0:11:17.545868
# calamancy dependecy parsing - parsed: 121664 ETA: 0:11:31.780148
# calamancy dependecy parsing - parsed: 121792 ETA: 0:11:15.821016
# calamancy dependecy parsing - parsed: 121920 ETA: 0:11:08.658027
# calamancy dependecy parsing - parsed: 122048 ETA: 0:11:02.720783
# calamancy dependecy parsing - parsed: 122176 ETA: 0:10:47.071569
# calamancy dependecy parsing - parsed: 122304 ETA: 0:10:51.150242
# calamancy dependecy parsing - parsed: 122432 ETA: 0:10:52.299009
# calamancy dependecy parsing - parsed: 122560 ETA: 0:11:08.751576
# calamancy dependecy parsing - parsed: 122688 ETA: 0:11:13.555501
# calamancy dependecy parsing - parsed: 122816 ETA: 0:11:29.125827
# calamancy dependecy parsing - parsed: 122944 ETA: 0:11:19.839100
# calamancy dependecy parsing - parsed: 123072 ETA: 0:11:26.344703
# calamancy dependecy parsing - parsed: 123200 ETA: 0:11:06.318835
# calamancy dependecy parsing - parsed: 123328 ETA: 0:10:53.489734
# calamancy dependecy parsing - parsed: 123456 ETA: 0:10:43.190074
# calamancy dependecy parsing - parsed: 123584 ETA: 0:10:29.147296
# calamancy dependecy parsing - parsed: 123712 ETA: 0:10:03.667996
# calamancy dependecy parsing - parsed: 123840 ETA: 0:09:53.365317
# calamancy dependecy parsing - parsed: 123968 ETA: 0:09:36.462819
# calamancy dependecy parsing - parsed: 124096 ETA: 0:09:33.058740
# calamancy dependecy parsing - parsed: 124224 ETA: 0:09:23.929082
# calamancy dependecy parsing - parsed: 124352 ETA: 0:10:17.984704
# calamancy dependecy parsing - parsed: 124480 ETA: 0:10:03.053584
# calamancy dependecy parsing - parsed: 124608 ETA: 0:09:55.695556
# calamancy dependecy parsing - parsed: 124736 ETA: 0:09:51.230680
# calamancy dependecy parsing - parsed: 124864 ETA: 0:09:48.960398
# calamancy dependecy parsing - parsed: 124992 ETA: 0:08:52.413745
# calamancy dependecy parsing - parsed: 125120 ETA: 0:09:23.226512
# calamancy dependecy parsing - parsed: 125248 ETA: 0:09:13.346512
# calamancy dependecy parsing - parsed: 125376 ETA: 0:08:59.354369
# calamancy dependecy parsing - parsed: 125504 ETA: 0:08:44.949619
# calamancy dependecy parsing - parsed: 125632 ETA: 0:08:47.131839
# calamancy dependecy parsing - parsed: 125760 ETA: 0:08:22.726160
# calamancy dependecy parsing - parsed: 125888 ETA: 0:08:30.417325
# calamancy dependecy parsing - parsed: 126016 ETA: 0:08:27.319376
# calamancy dependecy parsing - parsed: 126144 ETA: 0:08:30.795446
# calamancy dependecy parsing - parsed: 126272 ETA: 0:08:28.069423
# calamancy dependecy parsing - parsed: 126400 ETA: 0:08:11.699602
# calamancy dependecy parsing - parsed: 126528 ETA: 0:07:56.832087
# calamancy dependecy parsing - parsed: 126656 ETA: 0:07:55.274355
# calamancy dependecy parsing - parsed: 126784 ETA: 0:07:48.441007
# calamancy dependecy parsing - parsed: 126912 ETA: 0:07:37.192778
# calamancy dependecy parsing - parsed: 127040 ETA: 0:07:43.819786
# calamancy dependecy parsing - parsed: 127168 ETA: 0:07:47.022162
# calamancy dependecy parsing - parsed: 127296 ETA: 0:07:41.421760
# calamancy dependecy parsing - parsed: 127424 ETA: 0:07:28.038170
# calamancy dependecy parsing - parsed: 127552 ETA: 0:07:19.275971
# calamancy dependecy parsing - parsed: 127680 ETA: 0:07:22.365078
# calamancy dependecy parsing - parsed: 127808 ETA: 0:07:16.506302
# calamancy dependecy parsing - parsed: 127936 ETA: 0:06:59.064559
# calamancy dependecy parsing - parsed: 128064 ETA: 0:07:07.342094
# calamancy dependecy parsing - parsed: 128192 ETA: 0:06:54.930506
# calamancy dependecy parsing - parsed: 128320 ETA: 0:06:43.504713
# calamancy dependecy parsing - parsed: 128448 ETA: 0:06:40.972485
# calamancy dependecy parsing - parsed: 128576 ETA: 0:06:46.012329
# calamancy dependecy parsing - parsed: 128704 ETA: 0:06:41.478088
# calamancy dependecy parsing - parsed: 128832 ETA: 0:06:42.832692
# calamancy dependecy parsing - parsed: 128960 ETA: 0:06:34.897682
# calamancy dependecy parsing - parsed: 129088 ETA: 0:06:25.595835
# calamancy dependecy parsing - parsed: 129216 ETA: 0:06:12.645813
# calamancy dependecy parsing - parsed: 129344 ETA: 0:06:02.842170
# calamancy dependecy parsing - parsed: 129472 ETA: 0:05:52.932124
# calamancy dependecy parsing - parsed: 129600 ETA: 0:05:40.358749
# calamancy dependecy parsing - parsed: 129728 ETA: 0:05:30.657124
# calamancy dependecy parsing - parsed: 129856 ETA: 0:05:35.219067
# calamancy dependecy parsing - parsed: 129984 ETA: 0:05:31.496612
# calamancy dependecy parsing - parsed: 130112 ETA: 0:05:44.144521
# calamancy dependecy parsing - parsed: 130240 ETA: 0:05:47.113458
# calamancy dependecy parsing - parsed: 130368 ETA: 0:05:49.396778
# calamancy dependecy parsing - parsed: 130496 ETA: 0:05:33.610000
# calamancy dependecy parsing - parsed: 130624 ETA: 0:05:20.749824
# calamancy dependecy parsing - parsed: 130752 ETA: 0:05:00.852883
# calamancy dependecy parsing - parsed: 130880 ETA: 0:04:59.319666
# calamancy dependecy parsing - parsed: 131008 ETA: 0:04:56.825143
# calamancy dependecy parsing - parsed: 131136 ETA: 0:04:59.027522
# calamancy dependecy parsing - parsed: 131264 ETA: 0:05:03.340181
# calamancy dependecy parsing - parsed: 131392 ETA: 0:05:01.959456
# calamancy dependecy parsing - parsed: 131520 ETA: 0:04:56.521455
# calamancy dependecy parsing - parsed: 131648 ETA: 0:04:54.775754
# calamancy dependecy parsing - parsed: 131776 ETA: 0:04:45.175851
# calamancy dependecy parsing - parsed: 131904 ETA: 0:04:31.128568
# calamancy dependecy parsing - parsed: 132032 ETA: 0:04:23.001097
# calamancy dependecy parsing - parsed: 132160 ETA: 0:04:13.914186
# calamancy dependecy parsing - parsed: 132288 ETA: 0:04:00.601639
# calamancy dependecy parsing - parsed: 132416 ETA: 0:03:56.557674
# calamancy dependecy parsing - parsed: 132544 ETA: 0:03:50.425824
# calamancy dependecy parsing - parsed: 132672 ETA: 0:03:45.399997
# calamancy dependecy parsing - parsed: 132800 ETA: 0:03:40.614545
# calamancy dependecy parsing - parsed: 132928 ETA: 0:03:36.738059
# calamancy dependecy parsing - parsed: 133056 ETA: 0:03:31.849349
# calamancy dependecy parsing - parsed: 133184 ETA: 0:03:33.256791
# calamancy dependecy parsing - parsed: 133312 ETA: 0:03:27.115550
# calamancy dependecy parsing - parsed: 133440 ETA: 0:03:21.810343
# calamancy dependecy parsing - parsed: 133568 ETA: 0:03:18.393748
# calamancy dependecy parsing - parsed: 133696 ETA: 0:03:19.939032
# calamancy dependecy parsing - parsed: 133824 ETA: 0:03:20.209559
# calamancy dependecy parsing - parsed: 133952 ETA: 0:03:19.690374
# calamancy dependecy parsing - parsed: 134080 ETA: 0:03:16.061699
# calamancy dependecy parsing - parsed: 134208 ETA: 0:03:11.296384
# calamancy dependecy parsing - parsed: 134336 ETA: 0:03:08.779574
# calamancy dependecy parsing - parsed: 134464 ETA: 0:02:59.408085
# calamancy dependecy parsing - parsed: 134592 ETA: 0:02:55.765576
# calamancy dependecy parsing - parsed: 134720 ETA: 0:02:54.385477
# calamancy dependecy parsing - parsed: 134848 ETA: 0:02:51.350458
# calamancy dependecy parsing - parsed: 134976 ETA: 0:02:44.906483
# calamancy dependecy parsing - parsed: 135104 ETA: 0:02:42.330487
# calamancy dependecy parsing - parsed: 135232 ETA: 0:02:37.582045
# calamancy dependecy parsing - parsed: 135360 ETA: 0:02:30.475157
# calamancy dependecy parsing - parsed: 135488 ETA: 0:02:22.689091
# calamancy dependecy parsing - parsed: 135616 ETA: 0:02:14.165482
# calamancy dependecy parsing - parsed: 135744 ETA: 0:02:05.033167
# calamancy dependecy parsing - parsed: 135872 ETA: 0:01:58.764700
# calamancy dependecy parsing - parsed: 136000 ETA: 0:01:50.811534
# calamancy dependecy parsing - parsed: 136128 ETA: 0:01:49.145088
# calamancy dependecy parsing - parsed: 136256 ETA: 0:01:44.753163
# calamancy dependecy parsing - parsed: 136384 ETA: 0:01:38.903142
# calamancy dependecy parsing - parsed: 136512 ETA: 0:01:34.014982
# calamancy dependecy parsing - parsed: 136640 ETA: 0:01:30.551920
# calamancy dependecy parsing - parsed: 136768 ETA: 0:01:22.749258
# calamancy dependecy parsing - parsed: 136896 ETA: 0:01:16.418547
# calamancy dependecy parsing - parsed: 137024 ETA: 0:01:11.103988
# calamancy dependecy parsing - parsed: 137152 ETA: 0:01:05.656329
# calamancy dependecy parsing - parsed: 137280 ETA: 0:00:58.622655
# calamancy dependecy parsing - parsed: 137408 ETA: 0:00:54.776649
# calamancy dependecy parsing - parsed: 137536 ETA: 0:00:50.717533
# calamancy dependecy parsing - parsed: 137664 ETA: 0:00:47.853624
# calamancy dependecy parsing - parsed: 137792 ETA: 0:00:42.674251
# calamancy dependecy parsing - parsed: 137920 ETA: 0:00:39.333881
# calamancy dependecy parsing - parsed: 138048 ETA: 0:00:33.252439
# calamancy dependecy parsing - parsed: 138176 ETA: 0:00:28.494686
# calamancy dependecy parsing - parsed: 138304 ETA: 0:00:22.201576
# calamancy dependecy parsing - parsed: 138432 ETA: 0:00:17.882008
# calamancy dependecy parsing - parsed: 138560 ETA: 0:00:12.445780
#                 category           lemma just_category  \
# 0            person.n.01          person        person
# 1            person.n.01          person        person
# 2            person.n.01          person        person
# 3            person.n.01          person        person
# 4            person.n.01          person        person
# ...                  ...             ...           ...
# 138589  consequence.n.01  placebo_effect   consequence
# 138590  consequence.n.01  placebo_effect   consequence
# 138591  consequence.n.01  placebo_effect   consequence
# 138592  consequence.n.01  placebo_effect   consequence
# 138593  consequence.n.01  placebo_effect   consequence
#
#                                         in_sentenceV2  \
# 0                           The person ate the pizza.
# 1                         The person is at the store.
# 2                                The person is happy.
# 3                                    The person runs.
# 4                The person was invited to the party.
# ...                                               ...
# 138589             The placebo effect is on Saturday.
# 138590              The placebo effect is successful.
# 138591                   The placebo effect happened.
# 138592  The placebo effect was cancelled due to rain.
# 138593     The team gave the placebo effect an award.
#
#                                    translated_en_helsinki  \
# 0                      Ang taong iyon ay kumain ng pizza.
# 1                               Ang tao ay nasa tindahan.
# 2                                Maligaya ang taong iyon.
# 3                                      Tumatakbo ang tao.
# 4           Ang taong iyon ay inanyayahan sa salu - salo.
# ...                                                   ...
# 138589                Ang epekto ng placebo ay sa Sabado.
# 138590               Ang epekto ng placebo ay matagumpay.
# 138591                 Ang epekto ng placebo ay nangyari.
# 138592  Ang epekto ng placebo ay kinansela dahil sa ulan.
# 138593  Binigyan ng pangkat ng parangal ang epektong p...
#
#        nsubj_from_helsinki_en_tl
# 0                        [taong]
# 1                          [tao]
# 2                        [taong]
# 3                          [tao]
# 4                        [taong]
# ...                          ...
# 138589                  [epekto]
# 138590                  [epekto]
# 138591                  [epekto]
# 138592                  [epekto]
# 138593                [epektong]
#
# [138594 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 tl_df
#
# NameError: name 'tl_df' is not defined

# %% [markdown]
# # formatting for translation quality assessment

# %%
import pandas as pd

translated_to_tl = pd.read_csv("translated_helsinki_with_tl_dp.csv").drop(columns=['Unnamed: 0'])
translated_to_tl
# Out:
#                 category           lemma just_category  \
# 0            person.n.01          person        person
# 1            person.n.01          person        person
# 2            person.n.01          person        person
# 3            person.n.01          person        person
# 4            person.n.01          person        person
# ...                  ...             ...           ...
# 138589  consequence.n.01  placebo_effect   consequence
# 138590  consequence.n.01  placebo_effect   consequence
# 138591  consequence.n.01  placebo_effect   consequence
# 138592  consequence.n.01  placebo_effect   consequence
# 138593  consequence.n.01  placebo_effect   consequence
#
#                                         in_sentenceV2  \
# 0                           The person ate the pizza.
# 1                         The person is at the store.
# 2                                The person is happy.
# 3                                    The person runs.
# 4                The person was invited to the party.
# ...                                               ...
# 138589             The placebo effect is on Saturday.
# 138590              The placebo effect is successful.
# 138591                   The placebo effect happened.
# 138592  The placebo effect was cancelled due to rain.
# 138593     The team gave the placebo effect an award.
#
#                                    translated_en_helsinki  \
# 0                      Ang taong iyon ay kumain ng pizza.
# 1                               Ang tao ay nasa tindahan.
# 2                                Maligaya ang taong iyon.
# 3                                      Tumatakbo ang tao.
# 4           Ang taong iyon ay inanyayahan sa salu - salo.
# ...                                                   ...
# 138589                Ang epekto ng placebo ay sa Sabado.
# 138590               Ang epekto ng placebo ay matagumpay.
# 138591                 Ang epekto ng placebo ay nangyari.
# 138592  Ang epekto ng placebo ay kinansela dahil sa ulan.
# 138593  Binigyan ng pangkat ng parangal ang epektong p...
#
#        nsubj_from_helsinki_en_tl
# 0                        [taong]
# 1                          [tao]
# 2                        [taong]
# 3                          [tao]
# 4                        [taong]
# ...                          ...
# 138589                  [epekto]
# 138590                  [epekto]
# 138591                  [epekto]
# 138592                  [epekto]
# 138593                [epektong]
#
# [138594 rows x 6 columns]

# %%
translated_to_tl.dtypes
# Out:
# category                     object
# lemma                        object
# just_category                object
# in_sentenceV2                object
# translated_en_helsinki       object
# nsubj_from_helsinki_en_tl    object
# dtype: object

# %%
grouped = translated_to_tl.groupby(by=['lemma', 'just_category'])
#grouped.first()
listed_df = grouped.agg(list)
listed_df = listed_df.reset_index()
listed_df
# Out:
#            lemma just_category  \
# 0          'hood      location
# 1          'hood        object
# 2          a'man  organization
# 3         a-line        object
# 4         a-team  organization
# ...          ...           ...
# 23093       zulu        object
# 23094       zulu        person
# 23095       zuni        person
# 23096  zurvanism  organization
# 23097     zygote        object
#
#                                                 category  \
# 0      [location.n.01, location.n.01, location.n.01, ...
# 1      [object.n.01, object.n.01, object.n.01, object...
# 2      [organization.n.01, organization.n.01, organiz...
# 3      [object.n.01, object.n.01, object.n.01, object...
# 4      [organization.n.01, organization.n.01, organiz...
# ...                                                  ...
# 23093  [object.n.01, object.n.01, object.n.01, object...
# 23094  [person.n.01, person.n.01, person.n.01, person...
# 23095  [person.n.01, person.n.01, person.n.01, person...
# 23096  [organization.n.01, organization.n.01, organiz...
# 23097  [object.n.01, object.n.01, object.n.01, object...
#
#                                            in_sentenceV2  \
# 0      [People visit the 'hood., The 'hood is near th...
# 1      [The 'hood broke the window., The 'hood is on ...
# 2      [The a'man launched a new product., The a'man ...
# 3      [The a-line broke the window., The a-line is o...
# 4      [The a-team launched a new product., The a-tea...
# ...                                                  ...
# 23093  [The zulu broke the window., The zulu is on th...
# 23094  [The zulu ate the pizza., The zulu is at the s...
# 23095  [The zuni ate the pizza., The zuni is at the s...
# 23096  [The zurvanism launched a new product., The zu...
# 23097  [The zygote broke the window., The zygote is o...
#
#                                   translated_en_helsinki  \
# 0      [Dinadalaw ng mga tao ang 'hood., Malapit sa i...
# 1      [Nabali ang bintana dahil sa 'kaguluhan., Ang ...
# 2      [Ang a'man ay naglunsad ng isang bagong produk...
# 3      [Nabali ang bintana dahil sa a-line., Ang a-li...
# 4      [Ang a-team ay naglunsad ng isang bagong produ...
# ...                                                  ...
# 23093  [Nabali ang bintana dahil sa zulu., Nasa mesa ...
# 23094  [Kinain ng zulu ang pizza., Ang zulu ay nasa t...
# 23095  [Kinain ng zuni ang pizza., Ang zuni ay nasa t...
# 23096  [Ang zurvanismo ay naglunsad ng isang bagong p...
# 23097  [Nabali ang bintana dahil sa zygote., Nasa mes...
#
#                                nsubj_from_helsinki_en_tl
# 0      [[ang, ', hood], [ang, ', kanluran], [ang, ', ...
# 1      [[bintana], [], [', kapuua, '], [ang, ', kaput...
# 2      [[a'man], [a'man], [a'man], [tao], [a'man], [l...
# 3      [[bintana], [a, -, line], [a, -, line], [ang, ...
# 4      [[a, -, team], [a, -, team], [a, -, team], [a,...
# ...                                                  ...
# 23093  [[bintana], [zulu], [zulu], [zulu], [zulu], [a...
# 23094   [[pizza], [zulu], [zulu], [zulu], [zulu], [ako]]
# 23095   [[pizza], [zuni], [zuni], [zuni], [zuni], [ako]]
# 23096  [[zurvanismo], [zurvanismo], [zurvanismo], [zu...
# 23097  [[bintana], [zygote], [zygote], [zygote], [zyg...
#
# [23098 rows x 6 columns]

# %%
import re
def list_of_lists_to_dict(list_inp):
    final_dict = {}
    #print(list_inp)
    for in_list_string in list_inp:
        # a little string builder
        a = []
        for i in in_list_string.split(','):
            i_new = i
            i_new = i_new.replace("[",'')
            i_new = i_new.replace("]",'')
            i_new = i_new.replace(" ",'')
            a.append(i_new)

        #print(a)
        # check if the key exists:
        for i in a:
            if i not in final_dict.keys():
                final_dict[i] = 1
            else:
                final_dict[i] += 1
    return final_dict

listed_df["consolidated_nsubj_helsinki_tl"] = listed_df['nsubj_from_helsinki_en_tl'].apply(lambda x: list_of_lists_to_dict(x))
listed_df
# Out:
#            lemma just_category  \
# 0          'hood      location
# 1          'hood        object
# 2          a'man  organization
# 3         a-line        object
# 4         a-team  organization
# ...          ...           ...
# 23093       zulu        object
# 23094       zulu        person
# 23095       zuni        person
# 23096  zurvanism  organization
# 23097     zygote        object
#
#                                                 category  \
# 0      [location.n.01, location.n.01, location.n.01, ...
# 1      [object.n.01, object.n.01, object.n.01, object...
# 2      [organization.n.01, organization.n.01, organiz...
# 3      [object.n.01, object.n.01, object.n.01, object...
# 4      [organization.n.01, organization.n.01, organiz...
# ...                                                  ...
# 23093  [object.n.01, object.n.01, object.n.01, object...
# 23094  [person.n.01, person.n.01, person.n.01, person...
# 23095  [person.n.01, person.n.01, person.n.01, person...
# 23096  [organization.n.01, organization.n.01, organiz...
# 23097  [object.n.01, object.n.01, object.n.01, object...
#
#                                            in_sentenceV2  \
# 0      [People visit the 'hood., The 'hood is near th...
# 1      [The 'hood broke the window., The 'hood is on ...
# 2      [The a'man launched a new product., The a'man ...
# 3      [The a-line broke the window., The a-line is o...
# 4      [The a-team launched a new product., The a-tea...
# ...                                                  ...
# 23093  [The zulu broke the window., The zulu is on th...
# 23094  [The zulu ate the pizza., The zulu is at the s...
# 23095  [The zuni ate the pizza., The zuni is at the s...
# 23096  [The zurvanism launched a new product., The zu...
# 23097  [The zygote broke the window., The zygote is o...
#
#                                   translated_en_helsinki  \
# 0      [Dinadalaw ng mga tao ang 'hood., Malapit sa i...
# 1      [Nabali ang bintana dahil sa 'kaguluhan., Ang ...
# 2      [Ang a'man ay naglunsad ng isang bagong produk...
# 3      [Nabali ang bintana dahil sa a-line., Ang a-li...
# 4      [Ang a-team ay naglunsad ng isang bagong produ...
# ...                                                  ...
# 23093  [Nabali ang bintana dahil sa zulu., Nasa mesa ...
# 23094  [Kinain ng zulu ang pizza., Ang zulu ay nasa t...
# 23095  [Kinain ng zuni ang pizza., Ang zuni ay nasa t...
# 23096  [Ang zurvanismo ay naglunsad ng isang bagong p...
# 23097  [Nabali ang bintana dahil sa zygote., Nasa mes...
#
#                                nsubj_from_helsinki_en_tl  \
# 0      [[ang, ', hood], [ang, ', kanluran], [ang, ', ...
# 1      [[bintana], [], [', kapuua, '], [ang, ', kaput...
# 2      [[a'man], [a'man], [a'man], [tao], [a'man], [l...
# 3      [[bintana], [a, -, line], [a, -, line], [ang, ...
# 4      [[a, -, team], [a, -, team], [a, -, team], [a,...
# ...                                                  ...
# 23093  [[bintana], [zulu], [zulu], [zulu], [zulu], [a...
# 23094   [[pizza], [zulu], [zulu], [zulu], [zulu], [ako]]
# 23095   [[pizza], [zuni], [zuni], [zuni], [zuni], [ako]]
# 23096  [[zurvanismo], [zurvanismo], [zurvanismo], [zu...
# 23097  [[bintana], [zygote], [zygote], [zygote], [zyg...
#
#                           consolidated_nsubj_helsinki_tl
# 0      {'ang': 3, ''': 6, 'hood': 1, 'kanluran': 1, '...
# 1      {'bintana': 1, '': 1, ''': 4, 'kapuua': 2, 'an...
# 2                     {'a'man': 4, 'tao': 1, 'lupon': 1}
# 3      {'bintana': 1, 'a': 4, '-': 4, 'line': 4, 'ang...
# 4      {'a': 5, '-': 5, 'team': 5, 'Ang': 1, 'lupon': 1}
# ...                                                  ...
# 23093                {'bintana': 1, 'zulu': 4, 'ako': 1}
# 23094                  {'pizza': 1, 'zulu': 4, 'ako': 1}
# 23095                  {'pizza': 1, 'zuni': 4, 'ako': 1}
# 23096                      {'zurvanismo': 5, 'lupon': 1}
# 23097                        {'bintana': 1, 'zygote': 5}
#
# [23098 rows x 7 columns]

# %%
# a list of stopwords
tl_stopwords = [
    "ako",
    "'",
    "kanila",
    "ang",
    "pizza",
]

tl_stopwords = set(tl_stopwords)

# %%
def get_probable_nsubj(dict_inp):
    output_list = []
    #get max value from valid words
    max_val = 0
    for key in dict_inp.keys():
        if key not in tl_stopwords:
            if dict_inp[key] > max_val:
                max_val = dict_inp[key]
    #get the words with the max_val
    for key in dict_inp.keys():
        if key not in tl_stopwords:
            if dict_inp[key] == max_val:
                output_list.append(key)
    return output_list

listed_df['probable_nsubj'] = listed_df["consolidated_nsubj_helsinki_tl"].apply(lambda x: get_probable_nsubj(x))
listed_df
# Out:
#            lemma just_category  \
# 0          'hood      location
# 1          'hood        object
# 2          a'man  organization
# 3         a-line        object
# 4         a-team  organization
# ...          ...           ...
# 23093       zulu        object
# 23094       zulu        person
# 23095       zuni        person
# 23096  zurvanism  organization
# 23097     zygote        object
#
#                                                 category  \
# 0      [location.n.01, location.n.01, location.n.01, ...
# 1      [object.n.01, object.n.01, object.n.01, object...
# 2      [organization.n.01, organization.n.01, organiz...
# 3      [object.n.01, object.n.01, object.n.01, object...
# 4      [organization.n.01, organization.n.01, organiz...
# ...                                                  ...
# 23093  [object.n.01, object.n.01, object.n.01, object...
# 23094  [person.n.01, person.n.01, person.n.01, person...
# 23095  [person.n.01, person.n.01, person.n.01, person...
# 23096  [organization.n.01, organization.n.01, organiz...
# 23097  [object.n.01, object.n.01, object.n.01, object...
#
#                                            in_sentenceV2  \
# 0      [People visit the 'hood., The 'hood is near th...
# 1      [The 'hood broke the window., The 'hood is on ...
# 2      [The a'man launched a new product., The a'man ...
# 3      [The a-line broke the window., The a-line is o...
# 4      [The a-team launched a new product., The a-tea...
# ...                                                  ...
# 23093  [The zulu broke the window., The zulu is on th...
# 23094  [The zulu ate the pizza., The zulu is at the s...
# 23095  [The zuni ate the pizza., The zuni is at the s...
# 23096  [The zurvanism launched a new product., The zu...
# 23097  [The zygote broke the window., The zygote is o...
#
#                                   translated_en_helsinki  \
# 0      [Dinadalaw ng mga tao ang 'hood., Malapit sa i...
# 1      [Nabali ang bintana dahil sa 'kaguluhan., Ang ...
# 2      [Ang a'man ay naglunsad ng isang bagong produk...
# 3      [Nabali ang bintana dahil sa a-line., Ang a-li...
# 4      [Ang a-team ay naglunsad ng isang bagong produ...
# ...                                                  ...
# 23093  [Nabali ang bintana dahil sa zulu., Nasa mesa ...
# 23094  [Kinain ng zulu ang pizza., Ang zulu ay nasa t...
# 23095  [Kinain ng zuni ang pizza., Ang zuni ay nasa t...
# 23096  [Ang zurvanismo ay naglunsad ng isang bagong p...
# 23097  [Nabali ang bintana dahil sa zygote., Nasa mes...
#
#                                nsubj_from_helsinki_en_tl  \
# 0      [[ang, ', hood], [ang, ', kanluran], [ang, ', ...
# 1      [[bintana], [], [', kapuua, '], [ang, ', kaput...
# 2      [[a'man], [a'man], [a'man], [tao], [a'man], [l...
# 3      [[bintana], [a, -, line], [a, -, line], [ang, ...
# 4      [[a, -, team], [a, -, team], [a, -, team], [a,...
# ...                                                  ...
# 23093  [[bintana], [zulu], [zulu], [zulu], [zulu], [a...
# 23094   [[pizza], [zulu], [zulu], [zulu], [zulu], [ako]]
# 23095   [[pizza], [zuni], [zuni], [zuni], [zuni], [ako]]
# 23096  [[zurvanismo], [zurvanismo], [zurvanismo], [zu...
# 23097  [[bintana], [zygote], [zygote], [zygote], [zyg...
#
#                           consolidated_nsubj_helsinki_tl probable_nsubj
# 0      {'ang': 3, ''': 6, 'hood': 1, 'kanluran': 1, '...       [kapuua]
# 1      {'bintana': 1, '': 1, ''': 4, 'kapuua': 2, 'an...       [kapuua]
# 2                     {'a'man': 4, 'tao': 1, 'lupon': 1}        [a'man]
# 3      {'bintana': 1, 'a': 4, '-': 4, 'line': 4, 'ang...   [a, -, line]
# 4      {'a': 5, '-': 5, 'team': 5, 'Ang': 1, 'lupon': 1}   [a, -, team]
# ...                                                  ...            ...
# 23093                {'bintana': 1, 'zulu': 4, 'ako': 1}         [zulu]
# 23094                  {'pizza': 1, 'zulu': 4, 'ako': 1}         [zulu]
# 23095                  {'pizza': 1, 'zuni': 4, 'ako': 1}         [zuni]
# 23096                      {'zurvanismo': 5, 'lupon': 1}   [zurvanismo]
# 23097                        {'bintana': 1, 'zygote': 5}       [zygote]
#
# [23098 rows x 8 columns]

# %%
listed_df.to_json("translated_helsinki_tl_dp_nsubj.json")

# %%
keywords_category_tl = listed_df[['lemma','just_category','probable_nsubj']]
#keywords_category_tl.loc[listed_df['probable_nsubj'].str.len() > 1 ]
keywords_category_tl
# Out:
#            lemma just_category probable_nsubj
# 0          'hood      location       [kapuua]
# 1          'hood        object       [kapuua]
# 2          a'man  organization        [a'man]
# 3         a-line        object   [a, -, line]
# 4         a-team  organization   [a, -, team]
# ...          ...           ...            ...
# 23093       zulu        object         [zulu]
# 23094       zulu        person         [zulu]
# 23095       zuni        person         [zuni]
# 23096  zurvanism  organization   [zurvanismo]
# 23097     zygote        object       [zygote]
#
# [23098 rows x 3 columns]

# %%
def get_tl_for_categ(list_inp):
    if len(list_inp) >= 1 and len(list_inp) <= 2:
        return list_inp
    elif len(list_inp) >= 3:
        inp_copy = list_inp
        trio_words = []
        # check for trios
        start = 0
        end = 2
        while end < len(inp_copy):
            check_trio = [inp_copy[start], inp_copy[start+1], inp_copy[end]]
            if check_trio[1] == '-':
                trio_words.append(f"{inp_copy[start]}{inp_copy[start+1]}{inp_copy[end]}")
                inp_copy.pop(start)
                inp_copy.pop(start)
                inp_copy.pop(start)
            else:
                start += 1
                end += 1
        return list_inp+trio_words
        
keywords_category_tl['tl_word'] = keywords_category_tl['probable_nsubj'].apply(lambda x: get_tl_for_categ(x))
keywords_category_tl
# Out:
# C:\Users\Neptune\AppData\Local\Temp\ipykernel_24216\3968962891.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   keywords_category_tl['tl_word'] = keywords_category_tl['probable_nsubj'].apply(lambda x: get_tl_for_categ(x))
#            lemma just_category probable_nsubj       tl_word
# 0          'hood      location       [kapuua]      [kapuua]
# 1          'hood        object       [kapuua]      [kapuua]
# 2          a'man  organization        [a'man]       [a'man]
# 3         a-line        object             []      [a-line]
# 4         a-team  organization             []      [a-team]
# ...          ...           ...            ...           ...
# 23093       zulu        object         [zulu]        [zulu]
# 23094       zulu        person         [zulu]        [zulu]
# 23095       zuni        person         [zuni]        [zuni]
# 23096  zurvanism  organization   [zurvanismo]  [zurvanismo]
# 23097     zygote        object       [zygote]      [zygote]
#
# [23098 rows x 4 columns]

# %%
# don't run this alone, yung nauna muna
keywords_category_tl = keywords_category_tl[['just_category', 'tl_word']]
keywords_category_tl = keywords_category_tl.explode('tl_word')
keywords_category_tl = keywords_category_tl.groupby('just_category').agg(list).reset_index()
keywords_category_tl
# Out:
#     just_category                                            tl_word
# 0  administration  [administrasyon, burukrasya, pangasiwaan, pang...
# 1             aim     [layon, negosyo, grail, okasyon, punto, bagay]
# 2          animal  [aardvark, abalone, aborsiyon, abrocome, kalal...
# 3     consequence  [resulta, resulta, epekto, bariansiya, epekto,...
# 4           event  [awiting, pag-awit, pagtalikod, pag-aalsa, abd...
# 5        location  [kapuua, abbasya, dingding, katuwaan, acutment...
# 6          object  [kapuua, a-line, aba, ababa, abacus, taong, ab...
# 7    organization  [a'man, a-team, abecedarian, akademiko, akadem...
# 8          person  [taong, abbetor, alaga, abator, tagapag-awdisy...

# %%
# even simpler

person_list = keywords_category_tl.loc[keywords_category_tl['just_category'] == "person"]['tl_word'].values.tolist()[0]
object_list = keywords_category_tl.loc[keywords_category_tl['just_category'] == "object"]['tl_word'].values.tolist()[0] + keywords_category_tl.loc[keywords_category_tl['just_category'] == "aim"]['tl_word'].values.tolist()[0] 
location_list = keywords_category_tl.loc[keywords_category_tl['just_category'] == "location"]['tl_word'].values.tolist()[0]
organization_list = keywords_category_tl.loc[keywords_category_tl['just_category'] == "organization"]['tl_word'].values.tolist()[0] + keywords_category_tl.loc[keywords_category_tl['just_category'] == "administration"]['tl_word'].values.tolist()[0] 
event_list = keywords_category_tl.loc[keywords_category_tl['just_category'] == "event"]['tl_word'].values.tolist()[0] + keywords_category_tl.loc[keywords_category_tl['just_category'] == "consequence"]['tl_word'].values.tolist()[0] 
animal_list = keywords_category_tl.loc[keywords_category_tl['just_category'] == "animal"]['tl_word'].values.tolist()[0]

keywords_category_tl_final = pd.DataFrame({
    "TAO" : [person_list],
    "BAGAY" : [object_list],
    "LUGAR" : [location_list],
    "ORG" : [organization_list],
    "PANGYAYARI" : [event_list],
    "HAYOP" : [animal_list], 
})

keywords_category_tl_final
# Out:
#                                                  TAO  \
# 0  [taong, abbetor, alaga, abator, tagapag-awdisy...
#
#                                                BAGAY  \
# 0  [kapuua, a-line, aba, ababa, abacus, taong, ab...
#
#                                                LUGAR  \
# 0  [kapuua, abbasya, dingding, katuwaan, acutment...
#
#                                                  ORG  \
# 0  [a'man, a-team, abecedarian, akademiko, akadem...
#
#                                           PANGYAYARI  \
# 0  [awiting, pag-awit, pagtalikod, pag-aalsa, abd...
#
#                                                HAYOP
# 0  [aardvark, abalone, aborsiyon, abrocome, kalal...

# %%
keywords_category_tl_final.to_json("keyword_categ_tl_unassessed.json")
